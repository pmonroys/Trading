# %% [markdown]
# <img style="float: right; margin: 0px 0px 15px 15px;" src="https://educationusa.state.gov/sites/default/files/wysiwyg/iteso_logo.jpg" width="300px" height="300px" />
#
# `Trading Microstructure`
#
# **Ulises Rodrigo León Ortiz**
# **Bryan Edwin Castelan**
# **Paulina Raquel Monroy Salcido**
#
#
# ## 002 Technical Analysis

# %% [markdown]
# -Define buy/sell signals for each indicator.
# -Create all possible combinations of all technical indicators (2^5 - 1).
# -Backtest the strategies while keeping track of the operations and cash/portfolio value time series, remember that we'll be opening long & short positions.
# -Measure your strategy's Sharpe Ratio (using treasury bonds as reference), Max Drawdown and Win-Loss Ratio.
# -Optimize all technical indicator's parameters (TPE, Grid Search, PSO, Genetic Algorithms, ...), stop-loss/take-profit, volume of the trade, maximizing one of the previous metrics, consider the bounds of each variable!
# -Select the optimal strategy and describe it thoroughly (what indicators are used, when is the trade signal produced, etc.).
# -Now, use the optimal strategy with the test dataset and compare it to a passive strategy.

# %%
from TA import Operation, TechnicalAnalysis

# %%
strategy = TechnicalAnalysis('5m')
strategy

# %%
strategy.plot_ClosingPrices()

# %% [markdown]
# ### Relative Strength Index | RSI
#
# The Relative Strength Index (RSI) is a popular technical analysis tool used by traders to assess the momentum of an asset and pinpoint potential shifts in its trend. By evaluating whether an asset is overbought or oversold, the RSI provides traders with valuable signals, enabling them to make more strategic decisions in the market. This concise overview highlights the key principles of the RSI strategy and its effectiveness in helping traders navigate financial markets with greater precision.

# %%
strategy.plot_RSI()

# %% [markdown]
# The top graph illustrates the asset's closing prices over time, providing insight into its price fluctuations and trend trajectory. In the lower graph, the Relative Strength Index (RSI) is depicted, which is a momentum-based indicator that oscillates between 0 and 100. It highlights whether the asset could be considered overbought (values above 70) or oversold (values below 30). When the RSI crosses these upper (overbought) or lower (oversold) boundaries, it may signal potential reversal points or trend continuations. However, traders often combine the RSI with other technical tools to enhance the accuracy of their trading decisions.

# %% [markdown]
# ### Bollinger Bands
# Bollinger Bands are a technical analysis tool consisting of three lines: a middle band (usually a moving average) and two outer bands that represent standard deviations from the middle. These bands expand and contract based on market volatility. When prices move near the upper band, the asset may be considered overbought, while prices near the lower band might indicate an oversold condition. Traders use Bollinger Bands to identify potential price breakouts, reversals, and to assess market volatility.

# %%
strategy.plot_bollinger_bands()

# %% [markdown]
# The upper graph shows the closing prices of a financial asset, with Bollinger Bands overlaid to highlight price volatility. The middle line represents the asset’s moving average, while the outer bands indicate levels of standard deviation. When the price touches or moves close to the upper band, it may signal that the asset is overbought, while nearing the lower band could suggest an oversold condition. Traders often interpret price movements outside the bands as potential breakout signals, but it's essential to use Bollinger Bands alongside other indicators for more accurate trading decisions. The contraction or expansion of the bands also indicates changes in market volatility, with narrow bands suggesting low volatility and wide bands indicating high volatility.

# %% [markdown]
# ### Williams %R
# The Williams %R is a momentum oscillator that ranges from 0 to -100 and helps traders identify potential overbought or oversold conditions. In the strategy, a buy signal is triggered when the Williams %R falls below -80, indicating that the asset may be oversold, presenting a possible buying opportunity. A sell signal is generated when the Williams %R rises above -20, indicating the asset could be overbought and signaling a potential time to sell. This strategy aims to capture potential reversals in price trends by trading at these extreme conditions.

# %%
strategy.plot_williams_r()

# %% [markdown]
# The top graph shows the asset’s closing prices over time, reflecting the overall price movement and trends. In the lower graph, the Williams %R is plotted, ranging from 0 to -100. When the Williams %R dips below -80, it signals an oversold condition, prompting a buy signal. Conversely, when it rises above -20, an overbought condition is indicated, triggering a sell signal. These signals are intended to help traders identify potential entry and exit points based on momentum. However, it is recommended to use Williams %R in conjunction with other indicators for a more accurate analysis of market conditions.

# %% [markdown]
# ### MACD
# The Moving Average Convergence Divergence (MACD) is a popular trend-following indicator that tracks the relationship between two moving averages of an asset's price. The strategy uses two main components: the MACD line, which is the difference between the short-term and long-term moving averages, and the Signal Line, which is the moving average of the MACD line. In this strategy, a buy signal is generated when the MACD line crosses above the Signal Line, suggesting upward momentum. A sell signal is triggered when the MACD line crosses below the Signal Line, indicating potential downward momentum.

# %%
strategy.plot_MACD()

# %% [markdown]
# The upper graph shows the asset’s closing prices over time, depicting its general trend and movement. In the lower graph, the MACD line and Signal Line are plotted. A buy signal occurs when the MACD line crosses above the Signal Line, signaling the beginning of potential bullish momentum. Conversely, when the MACD line crosses below the Signal Line, a sell signal is triggered, suggesting possible bearish momentum. This strategy aims to help traders identify trend shifts. To increase accuracy, it is often used alongside other indicators or confirmation tools to better gauge

# %% [markdown]
# ### Stochastic Oscillator Strategy
# The Stochastic Oscillator is a momentum indicator used to assess the position of an asset's price relative to its price range over a specific period. It consists of two lines: %K, which measures the current price relative to the high-low range, and %D, which is a moving average of %K. In this strategy, a buy signal is triggered when %K crosses above %D while both lines are below 20, indicating the asset may be oversold. Conversely, a sell signal is generated when %K crosses below %D while both lines are above 80, signaling that the asset could be overbought.

# %%
strategy.plot_stochastic()

# %% [markdown]
# The top graph represents the asset’s closing prices over time, highlighting the trend and price movements. In the lower graph, the Stochastic Oscillator is plotted, showing both the %K and %D lines. A buy signal is activated when %K crosses above %D while below the 20 level, indicating oversold conditions and a potential upward reversal. On the other hand, a sell signal occurs when %K crosses below %D while above the 80 level, suggesting overbought conditions and a potential downward reversal. This strategy helps traders identify entry and exit points, but it is often used in combination with other technical indicators to improve accuracy and reliability in trading decisions.

# %% [markdown]
# ### Combinations
#
# In this section, combinations of strategies are tested. Strategies that together provide the best performance are selected, followed by obtaining ratios, optimizing, and conducting backtesting.

# %%
strategy.run_combinations()
# Out:
# Ejecutando con combinación de indicadores: ['RSI']
# Ejecutando con combinación de indicadores: ['Bollinger']
# Ejecutando con combinación de indicadores: ['Williams %R']
# Ejecutando con combinación de indicadores: ['MACD']
# Ejecutando con combinación de indicadores: ['Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger']
# Ejecutando con combinación de indicadores: ['RSI', 'Williams %R']
# Ejecutando con combinación de indicadores: ['RSI', 'MACD']
# Ejecutando con combinación de indicadores: ['RSI', 'Stoch']
# Ejecutando con combinación de indicadores: ['Bollinger', 'Williams %R']
# Ejecutando con combinación de indicadores: ['Bollinger', 'MACD']
# Ejecutando con combinación de indicadores: ['Bollinger', 'Stoch']
# Ejecutando con combinación de indicadores: ['Williams %R', 'MACD']
# Ejecutando con combinación de indicadores: ['Williams %R', 'Stoch']
# Ejecutando con combinación de indicadores: ['MACD', 'Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger', 'Williams %R']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger', 'MACD']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger', 'Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'Williams %R', 'MACD']
# Ejecutando con combinación de indicadores: ['RSI', 'Williams %R', 'Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'MACD', 'Stoch']
# Ejecutando con combinación de indicadores: ['Bollinger', 'Williams %R', 'MACD']
# Ejecutando con combinación de indicadores: ['Bollinger', 'Williams %R', 'Stoch']
# Ejecutando con combinación de indicadores: ['Bollinger', 'MACD', 'Stoch']
# Ejecutando con combinación de indicadores: ['Williams %R', 'MACD', 'Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger', 'Williams %R', 'MACD']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger', 'Williams %R', 'Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger', 'MACD', 'Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'Williams %R', 'MACD', 'Stoch']
# Ejecutando con combinación de indicadores: ['Bollinger', 'Williams %R', 'MACD', 'Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger', 'Williams %R', 'MACD', 'Stoch']
# Mejor combinación de indicadores: ['Williams %R', 'MACD'] con un valor de estrategia de: 1000030.1168559201

# %% [markdown]
# **The combination of strategies ['Williams %R', 'MACD'] achieves better performance together in the strategy.**

# %% [markdown]
# ### Ratios
#
# **Sharpe Ratio**: The Sharpe Ratio measures the risk-adjusted performance of an investment. Specifically, it calculates the excess return of an investment compared to a risk-free rate of return, divided by the standard deviation of the investment returns, which represents the risk. A higher Sharpe Ratio indicates that an investment has had better risk-adjusted performance, as for every unit of risk, the investment has generated more excess return.
#
# **Max Drawdown**: Max Drawdown represents the maximum loss that an investment could have experienced over a specific period. It is calculated as the largest drop from any peak to a subsequent low in the value of an investment account. This ratio is useful for measuring the maximum risk to which an investor was exposed and is considered an indicator of downward volatility.
#
# **Win-Loss Ratio**: The Win-Loss Ratio compares the number of winning periods to losing periods in a series of investments. It is calculated by dividing the number of trades or periods that generated profits by the number of trades or periods that resulted in losses. This ratio helps to understand the consistency of the gains of an investment strategy and is commonly used to evaluate the effectiveness of a trader or a trading strategy. A ratio greater than 1 indicates that there were more winning periods than losing ones.

# %%
from TA import Ratios
calculator = Ratios()

# Calcular el ratio de Sharpe
sharpe_ratio = calculator.calculate_sharpe_ratio()
print("Ratio de Sharpe calculado:", sharpe_ratio)

# Calcular el Max Drawdown
max_drawdown = calculator.calculate_max_drawdown()
print("Max Drawdown calculado:", max_drawdown)

# Calcular el Win-Loss Ratio
win_loss_ratio = calculator.calculate_win_loss_ratio()
print("Win-Loss Ratio calculado:", win_loss_ratio)
# Out:
# Ratio de Sharpe calculado: -1.5132522758697833
# Max Drawdown calculado: -0.2949618042719719
# Win-Loss Ratio calculado: 1.0114865214466808
# C:\Users\pmonr\Desktop\PAU ITESO\9NO SEMESTRE\TRADING\TA.py:699: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   data['Returns'] = data['Close'].pct_change()

# %% [markdown]
# ### Optimize parameters
# Optuna for optimizing the parameters of these indicators. The optimization process aims to fine-tune the trading strategies to enhance their effectiveness in identifying optimal entry and exit points in the market.

# %%
strategy.optimize_parameters()
# Out:
# [I 2024-09-26 16:48:55,225] A new study created in memory with name: no-name-a2b01e77-0578-4268-9472-9c9d0eee178f
# [I 2024-09-26 16:49:44,879] Trial 0 finished with value: 996426.8340520154 and parameters: {'n_shares': 27, 'williams_r_period': 24, 'macd_fast': 16, 'macd_slow': 38, 'macd_sign': 15}. Best is trial 0 with value: 996426.8340520154.
# [I 2024-09-26 16:50:35,947] Trial 1 finished with value: 957170.8836738653 and parameters: {'n_shares': 63, 'williams_r_period': 23, 'macd_fast': 10, 'macd_slow': 30, 'macd_sign': 7}. Best is trial 0 with value: 996426.8340520154.
# [I 2024-09-26 16:51:24,642] Trial 2 finished with value: 1000561.9957366518 and parameters: {'n_shares': 7, 'williams_r_period': 11, 'macd_fast': 19, 'macd_slow': 24, 'macd_sign': 9}. Best is trial 2 with value: 1000561.9957366518.
# [I 2024-09-26 16:52:15,328] Trial 3 finished with value: 963522.3257158577 and parameters: {'n_shares': 69, 'williams_r_period': 30, 'macd_fast': 11, 'macd_slow': 33, 'macd_sign': 14}. Best is trial 2 with value: 1000561.9957366518.
# [I 2024-09-26 16:53:04,022] Trial 4 finished with value: 1001650.6541629769 and parameters: {'n_shares': 59, 'williams_r_period': 15, 'macd_fast': 20, 'macd_slow': 30, 'macd_sign': 15}. Best is trial 4 with value: 1001650.6541629769.
# [I 2024-09-26 16:53:53,927] Trial 5 finished with value: 995380.4703439143 and parameters: {'n_shares': 46, 'williams_r_period': 19, 'macd_fast': 15, 'macd_slow': 38, 'macd_sign': 5}. Best is trial 4 with value: 1001650.6541629769.
# [I 2024-09-26 16:54:43,400] Trial 6 finished with value: 979361.1187378747 and parameters: {'n_shares': 75, 'williams_r_period': 15, 'macd_fast': 11, 'macd_slow': 38, 'macd_sign': 7}. Best is trial 4 with value: 1001650.6541629769.
# [I 2024-09-26 16:55:32,071] Trial 7 finished with value: 1000056.02505181 and parameters: {'n_shares': 30, 'williams_r_period': 8, 'macd_fast': 15, 'macd_slow': 38, 'macd_sign': 12}. Best is trial 4 with value: 1001650.6541629769.
# [I 2024-09-26 16:56:22,433] Trial 8 finished with value: 979522.49593339 and parameters: {'n_shares': 30, 'williams_r_period': 26, 'macd_fast': 12, 'macd_slow': 39, 'macd_sign': 9}. Best is trial 4 with value: 1001650.6541629769.
# [I 2024-09-26 16:57:11,057] Trial 9 finished with value: 1000302.0815053721 and parameters: {'n_shares': 17, 'williams_r_period': 15, 'macd_fast': 19, 'macd_slow': 28, 'macd_sign': 14}. Best is trial 4 with value: 1001650.6541629769.
# [I 2024-09-26 16:57:59,701] Trial 10 finished with value: 997657.1018206583 and parameters: {'n_shares': 98, 'williams_r_period': 5, 'macd_fast': 20, 'macd_slow': 23, 'macd_sign': 12}. Best is trial 4 with value: 1001650.6541629769.
# [I 2024-09-26 16:58:48,622] Trial 11 finished with value: 999888.1696436587 and parameters: {'n_shares': 3, 'williams_r_period': 11, 'macd_fast': 18, 'macd_slow': 21, 'macd_sign': 10}. Best is trial 4 with value: 1001650.6541629769.
# [I 2024-09-26 16:59:37,575] Trial 12 finished with value: 999679.066232426 and parameters: {'n_shares': 49, 'williams_r_period': 12, 'macd_fast': 17, 'macd_slow': 26, 'macd_sign': 12}. Best is trial 4 with value: 1001650.6541629769.
# [I 2024-09-26 17:00:27,273] Trial 13 finished with value: 1001984.2544007004 and parameters: {'n_shares': 85, 'williams_r_period': 19, 'macd_fast': 20, 'macd_slow': 32, 'macd_sign': 8}. Best is trial 13 with value: 1001984.2544007004.
# [I 2024-09-26 17:01:16,729] Trial 14 finished with value: 1003894.720343969 and parameters: {'n_shares': 91, 'williams_r_period': 19, 'macd_fast': 20, 'macd_slow': 32, 'macd_sign': 7}. Best is trial 14 with value: 1003894.720343969.
# [I 2024-09-26 17:02:07,500] Trial 15 finished with value: 964709.2355356935 and parameters: {'n_shares': 97, 'williams_r_period': 20, 'macd_fast': 14, 'macd_slow': 34, 'macd_sign': 6}. Best is trial 14 with value: 1003894.720343969.
# [I 2024-09-26 17:02:57,757] Trial 16 finished with value: 987959.9280789228 and parameters: {'n_shares': 82, 'williams_r_period': 21, 'macd_fast': 18, 'macd_slow': 34, 'macd_sign': 8}. Best is trial 14 with value: 1003894.720343969.
# [I 2024-09-26 17:03:49,101] Trial 17 finished with value: 954258.9585993993 and parameters: {'n_shares': 84, 'williams_r_period': 28, 'macd_fast': 20, 'macd_slow': 32, 'macd_sign': 5}. Best is trial 14 with value: 1003894.720343969.
# [I 2024-09-26 17:04:38,093] Trial 18 finished with value: 1002813.1047299526 and parameters: {'n_shares': 88, 'williams_r_period': 17, 'macd_fast': 17, 'macd_slow': 35, 'macd_sign': 7}. Best is trial 14 with value: 1003894.720343969.
# [I 2024-09-26 17:05:28,115] Trial 19 finished with value: 954360.2164782126 and parameters: {'n_shares': 91, 'williams_r_period': 23, 'macd_fast': 17, 'macd_slow': 35, 'macd_sign': 6}. Best is trial 14 with value: 1003894.720343969.
# [I 2024-09-26 17:06:17,023] Trial 20 finished with value: 1005317.7463045515 and parameters: {'n_shares': 74, 'williams_r_period': 15, 'macd_fast': 13, 'macd_slow': 35, 'macd_sign': 10}. Best is trial 20 with value: 1005317.7463045515.
# [I 2024-09-26 17:07:06,168] Trial 21 finished with value: 988847.1399988749 and parameters: {'n_shares': 73, 'williams_r_period': 16, 'macd_fast': 13, 'macd_slow': 36, 'macd_sign': 10}. Best is trial 20 with value: 1005317.7463045515.
# [I 2024-09-26 17:07:54,972] Trial 22 finished with value: 999039.4055515497 and parameters: {'n_shares': 89, 'williams_r_period': 13, 'macd_fast': 13, 'macd_slow': 36, 'macd_sign': 11}. Best is trial 20 with value: 1005317.7463045515.
# [I 2024-09-26 17:08:44,585] Trial 23 finished with value: 999289.0482679001 and parameters: {'n_shares': 100, 'williams_r_period': 17, 'macd_fast': 16, 'macd_slow': 28, 'macd_sign': 8}. Best is trial 20 with value: 1005317.7463045515.
# [I 2024-09-26 17:09:34,190] Trial 24 finished with value: 1015180.3955610594 and parameters: {'n_shares': 78, 'williams_r_period': 18, 'macd_fast': 14, 'macd_slow': 36, 'macd_sign': 7}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:10:24,008] Trial 25 finished with value: 990183.4482250481 and parameters: {'n_shares': 77, 'williams_r_period': 21, 'macd_fast': 14, 'macd_slow': 40, 'macd_sign': 9}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:11:12,664] Trial 26 finished with value: 989020.0345969001 and parameters: {'n_shares': 60, 'williams_r_period': 9, 'macd_fast': 13, 'macd_slow': 32, 'macd_sign': 6}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:12:02,199] Trial 27 finished with value: 1000645.3636692946 and parameters: {'n_shares': 54, 'williams_r_period': 18, 'macd_fast': 14, 'macd_slow': 36, 'macd_sign': 11}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:12:51,713] Trial 28 finished with value: 979813.157523295 and parameters: {'n_shares': 69, 'williams_r_period': 14, 'macd_fast': 12, 'macd_slow': 29, 'macd_sign': 8}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:13:42,026] Trial 29 finished with value: 980154.8807359785 and parameters: {'n_shares': 78, 'williams_r_period': 25, 'macd_fast': 16, 'macd_slow': 37, 'macd_sign': 10}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:14:32,440] Trial 30 finished with value: 942593.5238040952 and parameters: {'n_shares': 92, 'williams_r_period': 20, 'macd_fast': 12, 'macd_slow': 31, 'macd_sign': 7}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:15:21,435] Trial 31 finished with value: 999729.2780326664 and parameters: {'n_shares': 91, 'williams_r_period': 17, 'macd_fast': 17, 'macd_slow': 34, 'macd_sign': 7}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:16:11,968] Trial 32 finished with value: 979604.5267305431 and parameters: {'n_shares': 39, 'williams_r_period': 22, 'macd_fast': 14, 'macd_slow': 35, 'macd_sign': 6}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:17:01,549] Trial 33 finished with value: 1005442.3851033885 and parameters: {'n_shares': 81, 'williams_r_period': 17, 'macd_fast': 15, 'macd_slow': 33, 'macd_sign': 7}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:17:50,850] Trial 34 finished with value: 979093.9180235498 and parameters: {'n_shares': 66, 'williams_r_period': 13, 'macd_fast': 15, 'macd_slow': 33, 'macd_sign': 5}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:18:40,995] Trial 35 finished with value: 975375.7826157664 and parameters: {'n_shares': 81, 'williams_r_period': 18, 'macd_fast': 10, 'macd_slow': 31, 'macd_sign': 9}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:19:30,639] Trial 36 finished with value: 1002835.8156773096 and parameters: {'n_shares': 70, 'williams_r_period': 19, 'macd_fast': 16, 'macd_slow': 33, 'macd_sign': 8}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:20:20,291] Trial 37 finished with value: 991300.166734366 and parameters: {'n_shares': 63, 'williams_r_period': 16, 'macd_fast': 13, 'macd_slow': 37, 'macd_sign': 6}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:21:10,323] Trial 38 finished with value: 980524.2453985004 and parameters: {'n_shares': 54, 'williams_r_period': 24, 'macd_fast': 15, 'macd_slow': 30, 'macd_sign': 13}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:21:59,404] Trial 39 finished with value: 997640.6305245998 and parameters: {'n_shares': 73, 'williams_r_period': 10, 'macd_fast': 15, 'macd_slow': 37, 'macd_sign': 9}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:22:48,782] Trial 40 finished with value: 990902.8868957398 and parameters: {'n_shares': 95, 'williams_r_period': 14, 'macd_fast': 11, 'macd_slow': 40, 'macd_sign': 7}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:23:38,288] Trial 41 finished with value: 1002754.7923722436 and parameters: {'n_shares': 68, 'williams_r_period': 19, 'macd_fast': 16, 'macd_slow': 33, 'macd_sign': 8}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:24:27,789] Trial 42 finished with value: 998754.60616552 and parameters: {'n_shares': 80, 'williams_r_period': 16, 'macd_fast': 14, 'macd_slow': 33, 'macd_sign': 8}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:25:19,740] Trial 43 finished with value: 990799.93735585 and parameters: {'n_shares': 75, 'williams_r_period': 20, 'macd_fast': 19, 'macd_slow': 29, 'macd_sign': 7}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:26:09,368] Trial 44 finished with value: 998368.2728694003 and parameters: {'n_shares': 70, 'williams_r_period': 15, 'macd_fast': 18, 'macd_slow': 34, 'macd_sign': 7}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:27:00,093] Trial 45 finished with value: 961391.5457999074 and parameters: {'n_shares': 84, 'williams_r_period': 22, 'macd_fast': 15, 'macd_slow': 32, 'macd_sign': 9}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:27:50,003] Trial 46 finished with value: 1001049.1752222399 and parameters: {'n_shares': 60, 'williams_r_period': 19, 'macd_fast': 16, 'macd_slow': 31, 'macd_sign': 11}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:28:40,413] Trial 47 finished with value: 972030.8057728644 and parameters: {'n_shares': 64, 'williams_r_period': 18, 'macd_fast': 12, 'macd_slow': 35, 'macd_sign': 6}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:29:31,199] Trial 48 finished with value: 970250.6539508022 and parameters: {'n_shares': 41, 'williams_r_period': 21, 'macd_fast': 13, 'macd_slow': 39, 'macd_sign': 5}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:30:20,235] Trial 49 finished with value: 999685.116571768 and parameters: {'n_shares': 86, 'williams_r_period': 5, 'macd_fast': 19, 'macd_slow': 34, 'macd_sign': 8}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:31:09,041] Trial 50 finished with value: 988690.793015155 and parameters: {'n_shares': 95, 'williams_r_period': 12, 'macd_fast': 14, 'macd_slow': 26, 'macd_sign': 10}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:31:58,385] Trial 51 finished with value: 1002813.1047299526 and parameters: {'n_shares': 88, 'williams_r_period': 17, 'macd_fast': 17, 'macd_slow': 35, 'macd_sign': 7}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:32:48,067] Trial 52 finished with value: 1000070.9122377599 and parameters: {'n_shares': 80, 'williams_r_period': 16, 'macd_fast': 16, 'macd_slow': 33, 'macd_sign': 7}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:33:37,203] Trial 53 finished with value: 997794.3025397357 and parameters: {'n_shares': 74, 'williams_r_period': 14, 'macd_fast': 18, 'macd_slow': 36, 'macd_sign': 6}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:34:26,810] Trial 54 finished with value: 999580.7192620317 and parameters: {'n_shares': 16, 'williams_r_period': 18, 'macd_fast': 15, 'macd_slow': 35, 'macd_sign': 15}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:35:16,860] Trial 55 finished with value: 997972.2087679105 and parameters: {'n_shares': 86, 'williams_r_period': 20, 'macd_fast': 19, 'macd_slow': 32, 'macd_sign': 8}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:36:06,927] Trial 56 finished with value: 1006234.8441863476 and parameters: {'n_shares': 94, 'williams_r_period': 19, 'macd_fast': 16, 'macd_slow': 38, 'macd_sign': 9}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:36:56,839] Trial 57 finished with value: 989871.8340416001 and parameters: {'n_shares': 100, 'williams_r_period': 22, 'macd_fast': 16, 'macd_slow': 39, 'macd_sign': 9}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:37:46,545] Trial 58 finished with value: 1001689.1519745569 and parameters: {'n_shares': 94, 'williams_r_period': 19, 'macd_fast': 15, 'macd_slow': 38, 'macd_sign': 10}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:38:36,967] Trial 59 finished with value: 957233.2739117832 and parameters: {'n_shares': 79, 'williams_r_period': 23, 'macd_fast': 14, 'macd_slow': 37, 'macd_sign': 9}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:39:27,635] Trial 60 finished with value: 963268.7748555933 and parameters: {'n_shares': 71, 'williams_r_period': 28, 'macd_fast': 13, 'macd_slow': 36, 'macd_sign': 11}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:40:17,029] Trial 61 finished with value: 1003147.2227959429 and parameters: {'n_shares': 89, 'williams_r_period': 17, 'macd_fast': 17, 'macd_slow': 38, 'macd_sign': 8}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:41:05,830] Trial 62 finished with value: 1006300.3649971359 and parameters: {'n_shares': 84, 'williams_r_period': 16, 'macd_fast': 17, 'macd_slow': 38, 'macd_sign': 8}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:41:55,045] Trial 63 finished with value: 998629.52664781 and parameters: {'n_shares': 90, 'williams_r_period': 16, 'macd_fast': 17, 'macd_slow': 38, 'macd_sign': 9}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:42:44,137] Trial 64 finished with value: 997281.1765418483 and parameters: {'n_shares': 82, 'williams_r_period': 17, 'macd_fast': 20, 'macd_slow': 39, 'macd_sign': 8}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:43:33,337] Trial 65 finished with value: 999263.6974381122 and parameters: {'n_shares': 96, 'williams_r_period': 15, 'macd_fast': 17, 'macd_slow': 38, 'macd_sign': 7}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:44:22,703] Trial 66 finished with value: 998793.7640546535 and parameters: {'n_shares': 87, 'williams_r_period': 13, 'macd_fast': 18, 'macd_slow': 37, 'macd_sign': 10}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:45:11,953] Trial 67 finished with value: 1004878.8749579283 and parameters: {'n_shares': 93, 'williams_r_period': 15, 'macd_fast': 16, 'macd_slow': 40, 'macd_sign': 8}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:46:01,380] Trial 68 finished with value: 1014541.733953176 and parameters: {'n_shares': 92, 'williams_r_period': 15, 'macd_fast': 14, 'macd_slow': 40, 'macd_sign': 6}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:46:50,512] Trial 69 finished with value: 997166.6490477222 and parameters: {'n_shares': 77, 'williams_r_period': 14, 'macd_fast': 15, 'macd_slow': 40, 'macd_sign': 6}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:47:39,590] Trial 70 finished with value: 994822.2453532359 and parameters: {'n_shares': 93, 'williams_r_period': 12, 'macd_fast': 14, 'macd_slow': 40, 'macd_sign': 5}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:48:29,298] Trial 71 finished with value: 1008136.5996305159 and parameters: {'n_shares': 98, 'williams_r_period': 15, 'macd_fast': 12, 'macd_slow': 39, 'macd_sign': 7}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:49:18,748] Trial 72 finished with value: 1008136.5996305159 and parameters: {'n_shares': 98, 'williams_r_period': 15, 'macd_fast': 12, 'macd_slow': 39, 'macd_sign': 7}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:50:08,260] Trial 73 finished with value: 968535.7827702396 and parameters: {'n_shares': 98, 'williams_r_period': 11, 'macd_fast': 12, 'macd_slow': 39, 'macd_sign': 6}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:50:58,356] Trial 74 finished with value: 973718.4646996001 and parameters: {'n_shares': 100, 'williams_r_period': 15, 'macd_fast': 11, 'macd_slow': 39, 'macd_sign': 7}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:51:48,057] Trial 75 finished with value: 1006139.5008816398 and parameters: {'n_shares': 84, 'williams_r_period': 14, 'macd_fast': 12, 'macd_slow': 37, 'macd_sign': 7}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:52:37,929] Trial 76 finished with value: 962280.1079226641 and parameters: {'n_shares': 84, 'williams_r_period': 16, 'macd_fast': 10, 'macd_slow': 39, 'macd_sign': 7}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:53:27,789] Trial 77 finished with value: 967184.246334684 and parameters: {'n_shares': 92, 'williams_r_period': 13, 'macd_fast': 12, 'macd_slow': 37, 'macd_sign': 6}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:54:17,577] Trial 78 finished with value: 1009854.2737171844 and parameters: {'n_shares': 96, 'williams_r_period': 14, 'macd_fast': 12, 'macd_slow': 39, 'macd_sign': 7}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:55:07,180] Trial 79 finished with value: 973625.8544173335 and parameters: {'n_shares': 98, 'williams_r_period': 14, 'macd_fast': 12, 'macd_slow': 38, 'macd_sign': 6}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:55:56,285] Trial 80 finished with value: 982562.1464099209 and parameters: {'n_shares': 96, 'williams_r_period': 12, 'macd_fast': 11, 'macd_slow': 40, 'macd_sign': 7}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:56:45,457] Trial 81 finished with value: 1007271.31305529 and parameters: {'n_shares': 90, 'williams_r_period': 13, 'macd_fast': 12, 'macd_slow': 37, 'macd_sign': 7}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:57:35,297] Trial 82 finished with value: 977972.9227078712 and parameters: {'n_shares': 91, 'williams_r_period': 13, 'macd_fast': 11, 'macd_slow': 39, 'macd_sign': 7}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:58:25,041] Trial 83 finished with value: 996745.8271573656 and parameters: {'n_shares': 98, 'williams_r_period': 11, 'macd_fast': 12, 'macd_slow': 38, 'macd_sign': 7}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 17:59:14,023] Trial 84 finished with value: 998592.5035447429 and parameters: {'n_shares': 89, 'williams_r_period': 8, 'macd_fast': 13, 'macd_slow': 37, 'macd_sign': 8}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 18:00:04,298] Trial 85 finished with value: 963042.8823209809 and parameters: {'n_shares': 84, 'williams_r_period': 15, 'macd_fast': 11, 'macd_slow': 36, 'macd_sign': 6}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 18:00:53,361] Trial 86 finished with value: 1011078.6055625102 and parameters: {'n_shares': 95, 'williams_r_period': 14, 'macd_fast': 13, 'macd_slow': 40, 'macd_sign': 7}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 18:01:43,104] Trial 87 finished with value: 986783.6777710882 and parameters: {'n_shares': 94, 'williams_r_period': 16, 'macd_fast': 13, 'macd_slow': 40, 'macd_sign': 8}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 18:02:33,005] Trial 88 finished with value: 984761.9010034641 and parameters: {'n_shares': 97, 'williams_r_period': 10, 'macd_fast': 13, 'macd_slow': 38, 'macd_sign': 6}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 18:03:23,022] Trial 89 finished with value: 1003093.6537403584 and parameters: {'n_shares': 91, 'williams_r_period': 18, 'macd_fast': 12, 'macd_slow': 40, 'macd_sign': 8}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 18:04:12,832] Trial 90 finished with value: 978254.5717979003 and parameters: {'n_shares': 100, 'williams_r_period': 13, 'macd_fast': 13, 'macd_slow': 39, 'macd_sign': 5}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 18:05:02,476] Trial 91 finished with value: 1008930.435556198 and parameters: {'n_shares': 87, 'williams_r_period': 14, 'macd_fast': 12, 'macd_slow': 39, 'macd_sign': 7}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 18:05:51,794] Trial 92 finished with value: 1009033.0842407515 and parameters: {'n_shares': 88, 'williams_r_period': 14, 'macd_fast': 12, 'macd_slow': 39, 'macd_sign': 7}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 18:06:41,362] Trial 93 finished with value: 1008930.435556198 and parameters: {'n_shares': 87, 'williams_r_period': 14, 'macd_fast': 12, 'macd_slow': 39, 'macd_sign': 7}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 18:07:30,541] Trial 94 finished with value: 997821.1293654763 and parameters: {'n_shares': 87, 'williams_r_period': 12, 'macd_fast': 12, 'macd_slow': 39, 'macd_sign': 7}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 18:08:20,537] Trial 95 finished with value: 962513.9059273192 and parameters: {'n_shares': 88, 'williams_r_period': 14, 'macd_fast': 11, 'macd_slow': 40, 'macd_sign': 6}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 18:09:10,251] Trial 96 finished with value: 1007970.5465768323 and parameters: {'n_shares': 96, 'williams_r_period': 15, 'macd_fast': 12, 'macd_slow': 39, 'macd_sign': 7}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 18:09:59,722] Trial 97 finished with value: 1010957.8994081054 and parameters: {'n_shares': 95, 'williams_r_period': 15, 'macd_fast': 13, 'macd_slow': 40, 'macd_sign': 7}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 18:10:50,197] Trial 98 finished with value: 950818.4606718172 and parameters: {'n_shares': 93, 'williams_r_period': 14, 'macd_fast': 13, 'macd_slow': 21, 'macd_sign': 6}. Best is trial 24 with value: 1015180.3955610594.
# [I 2024-09-26 18:11:39,735] Trial 99 finished with value: 1011428.4562644836 and parameters: {'n_shares': 98, 'williams_r_period': 14, 'macd_fast': 13, 'macd_slow': 40, 'macd_sign': 7}. Best is trial 24 with value: 1015180.3955610594.
# Mejores parámetros encontrados: {'n_shares': 78, 'williams_r_period': 18, 'macd_fast': 14, 'macd_slow': 36, 'macd_sign': 7}

# %% [markdown]
# **The optimal parameters for the strategy are {'n_shares': 78, 'williams_r_period': 18, 'macd_fast': 14, 'macd_slow': 36, 'macd_sign': 7}, yielding a strategy value of $1,015,180.395561$**

# %% [markdown]
# Having optimized the parameters, we proceed to implement a strategy using the best parameters for the test dataset.

# %% [markdown]
# ### Passive Strategy

# %%
from TA import AssetPerformance

# %%
# Asegúrate de tener la ruta correcta al archivo de datos
performance = AssetPerformance("data/aapl_5m_test.csv")
rendimiento = performance.calculate_return()
print(f"The passive asset return from the first close to the last close is: {rendimiento:.2%}")
# Out:
# The passive asset return from the first close to the last close is: 48.28%

# %% [markdown]
# If a passive strategy had been used (entering at the first moment and exiting at the last without making any trades during that time), a return of **48.28%** would have been achieved.

# %%
performance.plot_close_price()

# %% [markdown]
# ### Test with Optimized Parameters

# %%
from TA import TestStrategy
# Out:
# C:\Users\pmonr\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\pmonr\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
strategy = TestStrategy('5m')
strategy

# %%
strategy.run_best()
# Out:
# Ejecutando con combinación de indicadores: ['Williams %R', 'MACD']
# Mejor combinación de indicadores: ['Williams %R', 'MACD'] con un valor de estrategia de: 1267981.907891853

# %% [markdown]
# After optimizing the parameters for the strategies in training, they are used to test the strategy on the test dataset, yielding a performance of **26.80%.**

# %% [markdown]
# This suggests that although it yielded positive outcomes (26.8%), it underperformed compared to a simple passive holding (48.28%) of the asset. This observation leads to a critical examination of the strategy's effectiveness and underscores the importance of continuously evaluating and adjusting investment strategies to optimize returns in the market.
