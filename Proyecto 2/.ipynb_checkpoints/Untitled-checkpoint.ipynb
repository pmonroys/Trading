# %% [raw]
# pip install optuna

# %% [raw]
# pip install ta

# %%
from Estrategias import Operation, TradingStrategy
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1884\2122073865.py in <module>
# ----> 1 from Estrategias import Operation, TradingStrategy, AssetPerformance
#
# ImportError: cannot import name 'AssetPerformance' from 'Estrategias' (C:\Users\pmonr\Desktop\PAU ITESO\9NO SEMESTRE\TRADING\Trading\Proyecto 2\Estrategias.py)

# %%
strategy = TradingStrategy('5m')
strategy

# %% [raw]
# strategy.show_ClosingPrices()

# %% [raw]
# strategy.show_RSI()

# %% [raw]
# strategy.show_bollinger_bands()

# %% [raw]
# strategy.show_williams_r()

# %% [raw]
# strategy.show_MACD()

# %% [raw]
# strategy.show_stochastic()

# %%
strategy.run_combinations()
# Out:
# Ejecutando con combinación de indicadores: ['RSI']
# Ejecutando con combinación de indicadores: ['Bollinger']
# Ejecutando con combinación de indicadores: ['Williams %R']
# Ejecutando con combinación de indicadores: ['MACD']
# Ejecutando con combinación de indicadores: ['Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger']
# Ejecutando con combinación de indicadores: ['RSI', 'Williams %R']
# Ejecutando con combinación de indicadores: ['RSI', 'MACD']
# Ejecutando con combinación de indicadores: ['RSI', 'Stoch']
# Ejecutando con combinación de indicadores: ['Bollinger', 'Williams %R']
# Ejecutando con combinación de indicadores: ['Bollinger', 'MACD']
# Ejecutando con combinación de indicadores: ['Bollinger', 'Stoch']
# Ejecutando con combinación de indicadores: ['Williams %R', 'MACD']
# Ejecutando con combinación de indicadores: ['Williams %R', 'Stoch']
# Ejecutando con combinación de indicadores: ['MACD', 'Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger', 'Williams %R']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger', 'MACD']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger', 'Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'Williams %R', 'MACD']
# Ejecutando con combinación de indicadores: ['RSI', 'Williams %R', 'Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'MACD', 'Stoch']
# Ejecutando con combinación de indicadores: ['Bollinger', 'Williams %R', 'MACD']
# Ejecutando con combinación de indicadores: ['Bollinger', 'Williams %R', 'Stoch']
# Ejecutando con combinación de indicadores: ['Bollinger', 'MACD', 'Stoch']
# Ejecutando con combinación de indicadores: ['Williams %R', 'MACD', 'Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger', 'Williams %R', 'MACD']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger', 'Williams %R', 'Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger', 'MACD', 'Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'Williams %R', 'MACD', 'Stoch']
# Ejecutando con combinación de indicadores: ['Bollinger', 'Williams %R', 'MACD', 'Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger', 'Williams %R', 'MACD', 'Stoch']
# Mejor combinación de indicadores: ['Williams %R', 'MACD'] con un valor de estrategia de: 1000030.1168559201

# %%
strategy.plot_results(best = True)

# %%
strategy.strategy_value[-1]
# Out:
# 1000030.1168559201

# %%
strategy.optimize_parameters()
# Out:
# [I 2024-09-26 13:50:50,684] A new study created in memory with name: no-name-36b6f06e-6989-491a-972f-8f20dfb6d2c6
# [I 2024-09-26 13:51:23,217] Trial 0 finished with value: 1000308.0753907494 and parameters: {'williams_r_period': 14, 'macd_fast': 15, 'macd_slow': 21, 'macd_sign': 11}. Best is trial 0 with value: 1000308.0753907494.
# [I 2024-09-26 13:51:56,737] Trial 1 finished with value: 999223.8269571799 and parameters: {'williams_r_period': 10, 'macd_fast': 20, 'macd_slow': 23, 'macd_sign': 7}. Best is trial 0 with value: 1000308.0753907494.
# [I 2024-09-26 13:52:27,358] Trial 2 finished with value: 999628.40777422 and parameters: {'williams_r_period': 7, 'macd_fast': 15, 'macd_slow': 27, 'macd_sign': 13}. Best is trial 0 with value: 1000308.0753907494.
# [I 2024-09-26 13:52:55,519] Trial 3 finished with value: 999949.6655433201 and parameters: {'williams_r_period': 8, 'macd_fast': 20, 'macd_slow': 29, 'macd_sign': 13}. Best is trial 0 with value: 1000308.0753907494.
# [I 2024-09-26 13:53:27,292] Trial 4 finished with value: 1000374.8316913401 and parameters: {'williams_r_period': 15, 'macd_fast': 14, 'macd_slow': 29, 'macd_sign': 15}. Best is trial 4 with value: 1000374.8316913401.
# [I 2024-09-26 13:53:58,119] Trial 5 finished with value: 994840.8770839098 and parameters: {'williams_r_period': 29, 'macd_fast': 13, 'macd_slow': 40, 'macd_sign': 13}. Best is trial 4 with value: 1000374.8316913401.
# [I 2024-09-26 13:54:28,309] Trial 6 finished with value: 996089.0928419096 and parameters: {'williams_r_period': 21, 'macd_fast': 10, 'macd_slow': 34, 'macd_sign': 11}. Best is trial 4 with value: 1000374.8316913401.
# [I 2024-09-26 13:54:58,558] Trial 7 finished with value: 999717.9564262999 and parameters: {'williams_r_period': 16, 'macd_fast': 19, 'macd_slow': 34, 'macd_sign': 12}. Best is trial 4 with value: 1000374.8316913401.
# [I 2024-09-26 13:55:29,735] Trial 8 finished with value: 999417.92605609 and parameters: {'williams_r_period': 9, 'macd_fast': 12, 'macd_slow': 28, 'macd_sign': 9}. Best is trial 4 with value: 1000374.8316913401.
# [I 2024-09-26 13:56:00,615] Trial 9 finished with value: 1000333.6706270899 and parameters: {'williams_r_period': 10, 'macd_fast': 20, 'macd_slow': 28, 'macd_sign': 11}. Best is trial 4 with value: 1000374.8316913401.
# Mejores parámetros encontrados: {'williams_r_period': 15, 'macd_fast': 14, 'macd_slow': 29, 'macd_sign': 15}

# %%
strategy.plot_results(best = True)

# %%
strategy.strategy_value
# Out:
# [1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1001316.43218007,
#  1001315.86211007,
#  1001315.3831300699,
#  1001313.4001000699,
#  1001313.3320500699,
#  1001313.18205007,
#  1001313.88213007,
#  1001315.5821100699,
#  1001315.38817007,
#  1001313.8320800699,
#  1001314.5820500699,
#  1001315.9811300699,
#  1001316.0810700699,
#  1001314.98213007,
#  1001315.48216007,
#  1001316.88216007,
#  1001315.48216007,
#  1001314.5820500699,
#  1001314.39818007,
#  1001313.68208007,
#  1001314.18211007,
#  1001315.28212007,
#  1001312.59810007,
#  1001310.28212007,
#  1001311.3320800699,
#  1001312.8321700699,
#  1001313.93218007,
#  1001314.3321100699,
#  1001314.84114007,
#  1001314.78209007,
#  1001313.5441500699,
#  1001315.98311007,
#  1001315.13213007,
#  1001314.63210007,
#  1001312.24104007,
#  1001311.09114007,
#  1001310.28212007,
#  1001309.88219007,
#  1001309.98213007,
#  1001311.68211007,
#  1001312.3561000699,
#  1001312.5820800699,
#  1001312.68218007,
#  1001314.03212007,
#  1001313.75517007,
#  1001312.5820800699,
#  1001312.38112007,
#  1001310.18218007,
#  1001311.0810700699,
#  1001310.18218007,
#  1001310.88210007,
#  1001311.2121400699,
#  1001314.48210007,
#  1001294.18211007,
#  1001289.21614007,
#  1001293.68315007,
#  1001286.43218007,
#  1001285.28105007,
#  1001285.40206007,
#  1001282.98216007,
#  1001281.0821400699,
#  1001278.68208007,
#  1001276.05010007,
#  1001278.47212007,
#  1001275.58608007,
#  1001277.13210007,
#  1001278.68208007,
#  1001277.97118007,
#  1001272.39714007,
#  1001272.48213007,
#  1001274.3321100699,
#  1001272.5190600699,
#  1001270.9161200699,
#  1001271.4111200699,
#  1001273.13216007,
#  1001273.48204007,
#  1001272.3321400699,
#  1001274.28206007,
#  1001276.18208007,
#  1001276.1891000699,
#  1001274.18211007,
#  1001272.78212007,
#  1001273.38210007,
#  1001274.74013007,
#  1001276.5130500699,
#  1001279.39711007,
#  1001280.1830900699,
#  1001277.2941500699,
#  1001275.68205007,
#  1001276.6271800699,
#  1001274.5820500699,
#  1001273.43215007,
#  1001272.37517007,
#  1001274.88219007,
#  1001272.53218007,
#  1001272.38219007,
#  1001271.28218007,
#  1001271.5891900699,
#  1001271.78206007,
#  1001272.37517007,
#  1001271.98210007,
#  1001272.98216007,
#  1001271.73216007,
#  1001270.18218007,
#  1001273.37508007,
#  1001274.68215007,
#  1001272.93211007,
#  1001271.68211007,
#  1001271.26204007,
#  1001270.23207007,
#  1001269.88219007,
#  1001268.18205007,
#  1001268.5671900699,
#  1001267.38310007,
#  1001267.93211007,
#  1001269.68215007,
#  1001269.0431100699,
#  1001269.88219007,
#  1001268.8320800699,
#  1001267.87413007,
#  1001267.23204007,
#  1001267.8321700699,
#  1001266.33605007,
#  1001264.79506007,
#  1001265.8831600699,
#  1001264.5820500699,
#  1001264.3321100699,
#  1001262.83507007,
#  1001261.78206007,
#  1001265.38008007,
#  1001265.5821100699,
#  1001276.78206007,
#  1001272.93211007,
#  1001262.82210007,
#  1001262.88207007,
#  1001265.68205007,
#  1001260.78215007,
#  1001262.13210007,
#  1001259.68108007,
#  1001261.8540800699,
#  1001262.85704007,
#  1001265.78215007,
#  1001268.03206007,
#  1001269.88219007,
#  1001272.78212007,
#  1001271.38213007,
#  1001273.06807007,
#  1001269.68215007,
#  1001265.38207007,
#  ...]

# %%
strategy.test()

# %%
strategy.strategy_value[-1]
# Out:
# 1000363.78748301

# %%
from Estrategias import AssetPerformance

# Asegúrate de tener la ruta correcta al archivo de datos
performance = AssetPerformance("data/aapl_5m_test.csv")
rendimiento = performance.calculate_return()
print(f"The passive asset return from the first close to the last close is: {rendimiento:.2%}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1884\1415768752.py in <module>
# ----> 1 from Estrategias import AssetPerformance
#       2
#       3 # Asegúrate de tener la ruta correcta al archivo de datos
#       4 performance = AssetPerformance("data/aapl_5m_test.csv")
#       5 rendimiento = performance.calculate_return()
#
# ImportError: cannot import name 'AssetPerformance' from 'Estrategias' (C:\Users\pmonr\Desktop\PAU ITESO\9NO SEMESTRE\TRADING\Trading\Proyecto 2\Estrategias.py)

# %%
# Convert the 'Date' column to datetime type
data['Date'] = pd.to_datetime(data['Date'])

# Get the closing price of the first and last data
first_close = data.iloc[0]['Close']
last_close = data.iloc[-1]['Close']

# Calculate the passive asset return
passive_return = (last_close - first_close) / first_close

print("The passive asset return from the first close to the last close is: {:.2%}".format(passive_return))

# Comparison with the strategy used
cash = 1000000
cash_final = 1107153.05
strategy_return = (cash_final - cash) / cash
print("The strategy return from the first close to the last close is: {:.2%}".format(strategy_return))

# Sort the data by date if they are not sorted
data = data.sort_values(by='Date')
plt.figure(figsize=(12, 8))
plt.plot(data['Date'], data['Close'], label='Closing Price', color='blue')
plt.title('Closing Price of the Asset')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend()
plt.grid(True)
plt.show()

# Calculate the cumulative return
data['Returns'] = data['Close'].pct_change().fillna(0)

# Calculate the cumulative value
initial_investment = cash
data['Investment_Value'] = (1 + data['Returns']).cumprod() * initial_investment
plt.figure(figsize=(12, 8))
plt.plot(data['Date'], data['Investment_Value'], label='Investment Value', color='green')
plt.title('Investment Return')
plt.xlabel('Date')
plt.ylabel('Investment Value')
plt.legend()
plt.grid(True)
plt.show()

final_value = data['Investment_Value'].iloc[-1]
print("The final value of the passive investment: ${:,.2f}".format(final_value))
