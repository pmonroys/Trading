# %% [raw]
# pip install optuna

# %% [raw]
# pip install ta

# %%
from Estrategias import Operation, TradingStrategy
# Out:
# C:\Users\pmonr\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\pmonr\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
strategy = TradingStrategy('5m')
strategy

# %% [raw]
# strategy.show_ClosingPrices()

# %% [raw]
# strategy.show_RSI()

# %% [raw]
# strategy.show_bollinger_bands()

# %% [raw]
# strategy.show_williams_r()

# %% [raw]
# strategy.show_MACD()

# %% [raw]
# strategy.show_stochastic()

# %%
strategy.run_combinations()
# Out:
# Ejecutando con combinación de indicadores: ['RSI']
# Ejecutando con combinación de indicadores: ['Bollinger']
# Ejecutando con combinación de indicadores: ['Williams %R']
# Ejecutando con combinación de indicadores: ['MACD']
# Ejecutando con combinación de indicadores: ['Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger']
# Ejecutando con combinación de indicadores: ['RSI', 'Williams %R']
# Ejecutando con combinación de indicadores: ['RSI', 'MACD']
# Ejecutando con combinación de indicadores: ['RSI', 'Stoch']
# Ejecutando con combinación de indicadores: ['Bollinger', 'Williams %R']
# Ejecutando con combinación de indicadores: ['Bollinger', 'MACD']
# Ejecutando con combinación de indicadores: ['Bollinger', 'Stoch']
# Ejecutando con combinación de indicadores: ['Williams %R', 'MACD']
# Ejecutando con combinación de indicadores: ['Williams %R', 'Stoch']
# Ejecutando con combinación de indicadores: ['MACD', 'Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger', 'Williams %R']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger', 'MACD']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger', 'Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'Williams %R', 'MACD']
# Ejecutando con combinación de indicadores: ['RSI', 'Williams %R', 'Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'MACD', 'Stoch']
# Ejecutando con combinación de indicadores: ['Bollinger', 'Williams %R', 'MACD']
# Ejecutando con combinación de indicadores: ['Bollinger', 'Williams %R', 'Stoch']
# Ejecutando con combinación de indicadores: ['Bollinger', 'MACD', 'Stoch']
# Ejecutando con combinación de indicadores: ['Williams %R', 'MACD', 'Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger', 'Williams %R', 'MACD']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger', 'Williams %R', 'Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger', 'MACD', 'Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'Williams %R', 'MACD', 'Stoch']
# Ejecutando con combinación de indicadores: ['Bollinger', 'Williams %R', 'MACD', 'Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger', 'Williams %R', 'MACD', 'Stoch']
# Mejor combinación de indicadores: ['Williams %R', 'MACD'] con un valor de estrategia de: 1000030.1168559201

# %%
strategy.plot_results(best = True)

# %%
strategy.strategy_value[-1]
# Out:
# 1000030.1168559201

# %%
strategy.optimize_parameters()
# Out:
# [I 2024-09-25 23:04:29,514] A new study created in memory with name: no-name-147c9321-e609-40b1-b69d-8f7bb8c9c4a2
# [I 2024-09-25 23:04:59,820] Trial 0 finished with value: 999160.12780819 and parameters: {'williams_r_period': 15, 'macd_fast': 16, 'macd_slow': 24, 'macd_sign': 15}. Best is trial 0 with value: 999160.12780819.
# [I 2024-09-25 23:05:30,189] Trial 1 finished with value: 995540.5227826897 and parameters: {'williams_r_period': 15, 'macd_fast': 11, 'macd_slow': 39, 'macd_sign': 5}. Best is trial 0 with value: 999160.12780819.
# [I 2024-09-25 23:05:59,313] Trial 2 finished with value: 1000648.5987642797 and parameters: {'williams_r_period': 12, 'macd_fast': 12, 'macd_slow': 36, 'macd_sign': 10}. Best is trial 2 with value: 1000648.5987642797.
# [I 2024-09-25 23:06:29,754] Trial 3 finished with value: 995837.7538968401 and parameters: {'williams_r_period': 15, 'macd_fast': 10, 'macd_slow': 40, 'macd_sign': 7}. Best is trial 2 with value: 1000648.5987642797.
# [I 2024-09-25 23:06:59,736] Trial 4 finished with value: 998158.8538695197 and parameters: {'williams_r_period': 21, 'macd_fast': 20, 'macd_slow': 26, 'macd_sign': 13}. Best is trial 2 with value: 1000648.5987642797.
# [I 2024-09-25 23:07:29,693] Trial 5 finished with value: 999975.77088514 and parameters: {'williams_r_period': 6, 'macd_fast': 10, 'macd_slow': 36, 'macd_sign': 8}. Best is trial 2 with value: 1000648.5987642797.
# [I 2024-09-25 23:07:59,550] Trial 6 finished with value: 997986.8066953598 and parameters: {'williams_r_period': 11, 'macd_fast': 15, 'macd_slow': 26, 'macd_sign': 6}. Best is trial 2 with value: 1000648.5987642797.
# [I 2024-09-25 23:08:28,861] Trial 7 finished with value: 999944.9644178599 and parameters: {'williams_r_period': 6, 'macd_fast': 18, 'macd_slow': 22, 'macd_sign': 7}. Best is trial 2 with value: 1000648.5987642797.
# [I 2024-09-25 23:09:00,110] Trial 8 finished with value: 998811.8182091899 and parameters: {'williams_r_period': 24, 'macd_fast': 18, 'macd_slow': 33, 'macd_sign': 14}. Best is trial 2 with value: 1000648.5987642797.
# [I 2024-09-25 23:09:30,046] Trial 9 finished with value: 999267.5737039701 and parameters: {'williams_r_period': 10, 'macd_fast': 16, 'macd_slow': 34, 'macd_sign': 9}. Best is trial 2 with value: 1000648.5987642797.
# [I 2024-09-25 23:10:00,944] Trial 10 finished with value: 993988.6748315505 and parameters: {'williams_r_period': 29, 'macd_fast': 13, 'macd_slow': 28, 'macd_sign': 11}. Best is trial 2 with value: 1000648.5987642797.
# [I 2024-09-25 23:10:29,937] Trial 11 finished with value: 999779.99769218 and parameters: {'williams_r_period': 6, 'macd_fast': 12, 'macd_slow': 36, 'macd_sign': 10}. Best is trial 2 with value: 1000648.5987642797.
# [I 2024-09-25 23:11:11,085] Trial 12 finished with value: 999455.79999934 and parameters: {'williams_r_period': 10, 'macd_fast': 13, 'macd_slow': 31, 'macd_sign': 9}. Best is trial 2 with value: 1000648.5987642797.
# [I 2024-09-25 23:11:41,178] Trial 13 finished with value: 999765.0357111199 and parameters: {'williams_r_period': 5, 'macd_fast': 10, 'macd_slow': 37, 'macd_sign': 11}. Best is trial 2 with value: 1000648.5987642797.
# [I 2024-09-25 23:12:11,078] Trial 14 finished with value: 999448.6663380597 and parameters: {'williams_r_period': 11, 'macd_fast': 12, 'macd_slow': 36, 'macd_sign': 8}. Best is trial 2 with value: 1000648.5987642797.
# [I 2024-09-25 23:12:40,968] Trial 15 finished with value: 1000758.41518731 and parameters: {'williams_r_period': 19, 'macd_fast': 14, 'macd_slow': 32, 'macd_sign': 12}. Best is trial 15 with value: 1000758.41518731.
# [I 2024-09-25 23:13:10,857] Trial 16 finished with value: 1000076.4926034594 and parameters: {'williams_r_period': 20, 'macd_fast': 14, 'macd_slow': 30, 'macd_sign': 12}. Best is trial 15 with value: 1000758.41518731.
# [I 2024-09-25 23:13:41,042] Trial 17 finished with value: 995848.2742744497 and parameters: {'williams_r_period': 26, 'macd_fast': 14, 'macd_slow': 33, 'macd_sign': 12}. Best is trial 15 with value: 1000758.41518731.
# [I 2024-09-25 23:14:10,982] Trial 18 finished with value: 1000631.0417583701 and parameters: {'williams_r_period': 19, 'macd_fast': 12, 'macd_slow': 30, 'macd_sign': 13}. Best is trial 15 with value: 1000758.41518731.
# [I 2024-09-25 23:14:58,064] Trial 19 finished with value: 1000091.2595274699 and parameters: {'williams_r_period': 17, 'macd_fast': 15, 'macd_slow': 38, 'macd_sign': 10}. Best is trial 15 with value: 1000758.41518731.
# [I 2024-09-25 23:15:28,818] Trial 20 finished with value: 994598.0341619804 and parameters: {'williams_r_period': 23, 'macd_fast': 13, 'macd_slow': 34, 'macd_sign': 11}. Best is trial 15 with value: 1000758.41518731.
# [I 2024-09-25 23:15:58,497] Trial 21 finished with value: 1000681.4407381401 and parameters: {'williams_r_period': 18, 'macd_fast': 12, 'macd_slow': 30, 'macd_sign': 13}. Best is trial 15 with value: 1000758.41518731.
# [I 2024-09-25 23:16:28,176] Trial 22 finished with value: 1001099.0146361699 and parameters: {'williams_r_period': 17, 'macd_fast': 11, 'macd_slow': 31, 'macd_sign': 15}. Best is trial 22 with value: 1001099.0146361699.
# [I 2024-09-25 23:16:57,938] Trial 23 finished with value: 1000112.1495271398 and parameters: {'williams_r_period': 17, 'macd_fast': 14, 'macd_slow': 28, 'macd_sign': 15}. Best is trial 22 with value: 1001099.0146361699.
# [I 2024-09-25 23:17:28,302] Trial 24 finished with value: 995619.4454435897 and parameters: {'williams_r_period': 22, 'macd_fast': 11, 'macd_slow': 31, 'macd_sign': 14}. Best is trial 22 with value: 1001099.0146361699.
# [I 2024-09-25 23:17:57,999] Trial 25 finished with value: 1000424.6586203204 and parameters: {'williams_r_period': 18, 'macd_fast': 11, 'macd_slow': 28, 'macd_sign': 14}. Best is trial 22 with value: 1001099.0146361699.
# [I 2024-09-25 23:18:29,251] Trial 26 finished with value: 994172.0484863799 and parameters: {'williams_r_period': 25, 'macd_fast': 11, 'macd_slow': 32, 'macd_sign': 13}. Best is trial 22 with value: 1001099.0146361699.
# [I 2024-09-25 23:18:58,906] Trial 27 finished with value: 999360.9645241895 and parameters: {'williams_r_period': 13, 'macd_fast': 13, 'macd_slow': 29, 'macd_sign': 15}. Best is trial 22 with value: 1001099.0146361699.
# [I 2024-09-25 23:19:30,869] Trial 28 finished with value: 995056.0130782899 and parameters: {'williams_r_period': 27, 'macd_fast': 16, 'macd_slow': 26, 'macd_sign': 12}. Best is trial 22 with value: 1001099.0146361699.
# [I 2024-09-25 23:20:01,071] Trial 29 finished with value: 1000075.0493269198 and parameters: {'williams_r_period': 16, 'macd_fast': 14, 'macd_slow': 21, 'macd_sign': 15}. Best is trial 22 with value: 1001099.0146361699.
# [I 2024-09-25 23:20:31,205] Trial 30 finished with value: 1000520.1454314002 and parameters: {'williams_r_period': 20, 'macd_fast': 17, 'macd_slow': 24, 'macd_sign': 14}. Best is trial 22 with value: 1001099.0146361699.
# [I 2024-09-25 23:21:01,625] Trial 31 finished with value: 999692.0805151397 and parameters: {'williams_r_period': 13, 'macd_fast': 12, 'macd_slow': 34, 'macd_sign': 12}. Best is trial 22 with value: 1001099.0146361699.
# [I 2024-09-25 23:21:31,433] Trial 32 finished with value: 999892.4931100596 and parameters: {'williams_r_period': 13, 'macd_fast': 12, 'macd_slow': 32, 'macd_sign': 13}. Best is trial 22 with value: 1001099.0146361699.
# [I 2024-09-25 23:22:01,157] Trial 33 finished with value: 1000999.9431246298 and parameters: {'williams_r_period': 15, 'macd_fast': 11, 'macd_slow': 35, 'macd_sign': 11}. Best is trial 22 with value: 1001099.0146361699.
# [I 2024-09-25 23:22:30,950] Trial 34 finished with value: 1000105.1492620396 and parameters: {'williams_r_period': 15, 'macd_fast': 11, 'macd_slow': 32, 'macd_sign': 11}. Best is trial 22 with value: 1001099.0146361699.
# [I 2024-09-25 23:23:00,592] Trial 35 finished with value: 1000718.6143654794 and parameters: {'williams_r_period': 15, 'macd_fast': 10, 'macd_slow': 35, 'macd_sign': 13}. Best is trial 22 with value: 1001099.0146361699.
# [I 2024-09-25 23:23:31,824] Trial 36 finished with value: 1001011.9157195598 and parameters: {'williams_r_period': 15, 'macd_fast': 10, 'macd_slow': 35, 'macd_sign': 12}. Best is trial 22 with value: 1001099.0146361699.
# [I 2024-09-25 23:24:01,591] Trial 37 finished with value: 999773.0992949802 and parameters: {'williams_r_period': 8, 'macd_fast': 10, 'macd_slow': 39, 'macd_sign': 9}. Best is trial 22 with value: 1001099.0146361699.
# [I 2024-09-25 23:24:32,162] Trial 38 finished with value: 995014.9738084994 and parameters: {'williams_r_period': 14, 'macd_fast': 11, 'macd_slow': 35, 'macd_sign': 5}. Best is trial 22 with value: 1001099.0146361699.
# [I 2024-09-25 23:25:03,229] Trial 39 finished with value: 997545.1947616397 and parameters: {'williams_r_period': 21, 'macd_fast': 10, 'macd_slow': 40, 'macd_sign': 11}. Best is trial 22 with value: 1001099.0146361699.
# [I 2024-09-25 23:25:33,167] Trial 40 finished with value: 999809.3734116596 and parameters: {'williams_r_period': 16, 'macd_fast': 20, 'macd_slow': 38, 'macd_sign': 10}. Best is trial 22 with value: 1001099.0146361699.
# [I 2024-09-25 23:26:02,975] Trial 41 finished with value: 1000511.4981897101 and parameters: {'williams_r_period': 16, 'macd_fast': 10, 'macd_slow': 35, 'macd_sign': 12}. Best is trial 22 with value: 1001099.0146361699.
# [I 2024-09-25 23:26:32,672] Trial 42 finished with value: 1001234.8091205697 and parameters: {'williams_r_period': 15, 'macd_fast': 10, 'macd_slow': 33, 'macd_sign': 13}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:27:02,868] Trial 43 finished with value: 1000314.8301890598 and parameters: {'williams_r_period': 19, 'macd_fast': 10, 'macd_slow': 33, 'macd_sign': 14}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:27:32,448] Trial 44 finished with value: 1000725.6140963794 and parameters: {'williams_r_period': 14, 'macd_fast': 11, 'macd_slow': 34, 'macd_sign': 12}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:28:02,255] Trial 45 finished with value: 1000255.5591352897 and parameters: {'williams_r_period': 11, 'macd_fast': 11, 'macd_slow': 37, 'macd_sign': 11}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:28:32,633] Trial 46 finished with value: 998182.3921282492 and parameters: {'williams_r_period': 19, 'macd_fast': 11, 'macd_slow': 32, 'macd_sign': 10}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:29:02,215] Trial 47 finished with value: 1000569.4486983796 and parameters: {'williams_r_period': 14, 'macd_fast': 10, 'macd_slow': 33, 'macd_sign': 14}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:29:32,139] Trial 48 finished with value: 1000939.0730501701 and parameters: {'williams_r_period': 17, 'macd_fast': 13, 'macd_slow': 31, 'macd_sign': 13}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:30:02,339] Trial 49 finished with value: 1000001.52442531 and parameters: {'williams_r_period': 12, 'macd_fast': 13, 'macd_slow': 31, 'macd_sign': 13}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:30:31,691] Trial 50 finished with value: 1000417.1721697799 and parameters: {'williams_r_period': 17, 'macd_fast': 12, 'macd_slow': 29, 'macd_sign': 14}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:31:01,098] Trial 51 finished with value: 999221.9124852995 and parameters: {'williams_r_period': 16, 'macd_fast': 15, 'macd_slow': 36, 'macd_sign': 12}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:31:30,964] Trial 52 finished with value: 1000333.01667567 and parameters: {'williams_r_period': 18, 'macd_fast': 13, 'macd_slow': 33, 'macd_sign': 11}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:32:01,350] Trial 53 finished with value: 1000942.5167960292 and parameters: {'williams_r_period': 20, 'macd_fast': 15, 'macd_slow': 35, 'macd_sign': 12}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:32:31,359] Trial 54 finished with value: 999209.3793138588 and parameters: {'williams_r_period': 21, 'macd_fast': 18, 'macd_slow': 37, 'macd_sign': 13}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:33:01,292] Trial 55 finished with value: 999442.3366532595 and parameters: {'williams_r_period': 15, 'macd_fast': 10, 'macd_slow': 35, 'macd_sign': 15}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:33:31,113] Trial 56 finished with value: 998433.776386119 and parameters: {'williams_r_period': 20, 'macd_fast': 19, 'macd_slow': 34, 'macd_sign': 13}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:34:01,563] Trial 57 finished with value: 995933.18217547 and parameters: {'williams_r_period': 23, 'macd_fast': 16, 'macd_slow': 31, 'macd_sign': 11}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:34:31,820] Trial 58 finished with value: 1000091.2595274699 and parameters: {'williams_r_period': 17, 'macd_fast': 15, 'macd_slow': 38, 'macd_sign': 10}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:35:01,533] Trial 59 finished with value: 999423.0468188501 and parameters: {'williams_r_period': 8, 'macd_fast': 11, 'macd_slow': 36, 'macd_sign': 12}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:35:30,985] Trial 60 finished with value: 999272.4273153996 and parameters: {'williams_r_period': 12, 'macd_fast': 12, 'macd_slow': 27, 'macd_sign': 13}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:36:00,406] Trial 61 finished with value: 1000143.0062000898 and parameters: {'williams_r_period': 18, 'macd_fast': 14, 'macd_slow': 33, 'macd_sign': 12}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:36:30,184] Trial 62 finished with value: 1001077.44161607 and parameters: {'williams_r_period': 19, 'macd_fast': 15, 'macd_slow': 32, 'macd_sign': 11}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:37:00,852] Trial 63 finished with value: 997755.1371496699 and parameters: {'williams_r_period': 22, 'macd_fast': 17, 'macd_slow': 29, 'macd_sign': 11}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:37:30,530] Trial 64 finished with value: 1000110.5170136198 and parameters: {'williams_r_period': 16, 'macd_fast': 16, 'macd_slow': 34, 'macd_sign': 11}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:38:00,771] Trial 65 finished with value: 998871.20754951 and parameters: {'williams_r_period': 20, 'macd_fast': 15, 'macd_slow': 30, 'macd_sign': 9}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:38:30,552] Trial 66 finished with value: 999988.5912176898 and parameters: {'williams_r_period': 17, 'macd_fast': 10, 'macd_slow': 31, 'macd_sign': 12}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:39:01,686] Trial 67 finished with value: 995534.0466446998 and parameters: {'williams_r_period': 30, 'macd_fast': 17, 'macd_slow': 32, 'macd_sign': 10}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:39:31,635] Trial 68 finished with value: 1000293.1341303298 and parameters: {'williams_r_period': 14, 'macd_fast': 14, 'macd_slow': 35, 'macd_sign': 15}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:40:01,861] Trial 69 finished with value: 1000197.7555802701 and parameters: {'williams_r_period': 19, 'macd_fast': 11, 'macd_slow': 33, 'macd_sign': 12}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:40:31,732] Trial 70 finished with value: 999160.2261930093 and parameters: {'williams_r_period': 18, 'macd_fast': 13, 'macd_slow': 36, 'macd_sign': 14}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:41:02,058] Trial 71 finished with value: 1000152.1946801699 and parameters: {'williams_r_period': 19, 'macd_fast': 15, 'macd_slow': 32, 'macd_sign': 13}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:41:31,801] Trial 72 finished with value: 999113.4185531097 and parameters: {'williams_r_period': 15, 'macd_fast': 15, 'macd_slow': 31, 'macd_sign': 12}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:42:01,620] Trial 73 finished with value: 1000534.7221158602 and parameters: {'williams_r_period': 17, 'macd_fast': 14, 'macd_slow': 30, 'macd_sign': 11}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:42:31,824] Trial 74 finished with value: 1000476.7547185901 and parameters: {'williams_r_period': 21, 'macd_fast': 14, 'macd_slow': 35, 'macd_sign': 12}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:43:02,144] Trial 75 finished with value: 1000633.4534056303 and parameters: {'williams_r_period': 22, 'macd_fast': 15, 'macd_slow': 34, 'macd_sign': 11}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:43:31,753] Trial 76 finished with value: 1000904.81348834 and parameters: {'williams_r_period': 13, 'macd_fast': 10, 'macd_slow': 32, 'macd_sign': 13}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:44:01,259] Trial 77 finished with value: 1001198.7850482498 and parameters: {'williams_r_period': 13, 'macd_fast': 10, 'macd_slow': 33, 'macd_sign': 13}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:44:31,183] Trial 78 finished with value: 999450.2785010501 and parameters: {'williams_r_period': 10, 'macd_fast': 10, 'macd_slow': 33, 'macd_sign': 14}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:45:01,081] Trial 79 finished with value: 999817.4505913097 and parameters: {'williams_r_period': 15, 'macd_fast': 11, 'macd_slow': 37, 'macd_sign': 13}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:45:30,660] Trial 80 finished with value: 1000723.0113962793 and parameters: {'williams_r_period': 14, 'macd_fast': 10, 'macd_slow': 34, 'macd_sign': 13}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:45:59,974] Trial 81 finished with value: 1000904.81348834 and parameters: {'williams_r_period': 13, 'macd_fast': 10, 'macd_slow': 32, 'macd_sign': 13}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:46:29,558] Trial 82 finished with value: 999230.4231725895 and parameters: {'williams_r_period': 12, 'macd_fast': 10, 'macd_slow': 31, 'macd_sign': 12}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:46:59,434] Trial 83 finished with value: 999000.1697409698 and parameters: {'williams_r_period': 16, 'macd_fast': 11, 'macd_slow': 32, 'macd_sign': 14}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:47:29,182] Trial 84 finished with value: 999068.2951142697 and parameters: {'williams_r_period': 13, 'macd_fast': 10, 'macd_slow': 30, 'macd_sign': 13}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:47:59,053] Trial 85 finished with value: 999376.6501312797 and parameters: {'williams_r_period': 15, 'macd_fast': 12, 'macd_slow': 33, 'macd_sign': 14}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:48:28,797] Trial 86 finished with value: 1000490.4400652196 and parameters: {'williams_r_period': 12, 'macd_fast': 11, 'macd_slow': 35, 'macd_sign': 12}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:48:58,621] Trial 87 finished with value: 1000723.0113962793 and parameters: {'williams_r_period': 14, 'macd_fast': 10, 'macd_slow': 34, 'macd_sign': 13}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:49:28,527] Trial 88 finished with value: 999576.5162172099 and parameters: {'williams_r_period': 11, 'macd_fast': 11, 'macd_slow': 32, 'macd_sign': 15}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:49:59,025] Trial 89 finished with value: 999506.1483067893 and parameters: {'williams_r_period': 16, 'macd_fast': 10, 'macd_slow': 29, 'macd_sign': 11}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:50:29,093] Trial 90 finished with value: 1000356.87189308 and parameters: {'williams_r_period': 18, 'macd_fast': 11, 'macd_slow': 31, 'macd_sign': 13}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:50:59,407] Trial 91 finished with value: 995613.50749255 and parameters: {'williams_r_period': 14, 'macd_fast': 10, 'macd_slow': 33, 'macd_sign': 8}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:51:30,032] Trial 92 finished with value: 1000904.81348834 and parameters: {'williams_r_period': 13, 'macd_fast': 10, 'macd_slow': 32, 'macd_sign': 13}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:51:59,670] Trial 93 finished with value: 999840.2590739899 and parameters: {'williams_r_period': 10, 'macd_fast': 10, 'macd_slow': 34, 'macd_sign': 12}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:52:29,044] Trial 94 finished with value: 1000570.6303613596 and parameters: {'williams_r_period': 13, 'macd_fast': 11, 'macd_slow': 32, 'macd_sign': 13}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:52:58,744] Trial 95 finished with value: 1000334.2320373396 and parameters: {'williams_r_period': 15, 'macd_fast': 10, 'macd_slow': 33, 'macd_sign': 12}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:53:28,456] Trial 96 finished with value: 1000534.7221158602 and parameters: {'williams_r_period': 17, 'macd_fast': 11, 'macd_slow': 30, 'macd_sign': 14}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:53:57,922] Trial 97 finished with value: 1000787.0370118999 and parameters: {'williams_r_period': 12, 'macd_fast': 12, 'macd_slow': 31, 'macd_sign': 13}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:54:27,589] Trial 98 finished with value: 999602.3231900301 and parameters: {'williams_r_period': 9, 'macd_fast': 10, 'macd_slow': 36, 'macd_sign': 14}. Best is trial 42 with value: 1001234.8091205697.
# [I 2024-09-25 23:54:57,589] Trial 99 finished with value: 997994.7486761098 and parameters: {'williams_r_period': 20, 'macd_fast': 10, 'macd_slow': 35, 'macd_sign': 11}. Best is trial 42 with value: 1001234.8091205697.
# Mejores parámetros encontrados: {'williams_r_period': 15, 'macd_fast': 10, 'macd_slow': 33, 'macd_sign': 13}

# %%
strategy.plot_results(best = True)

# %%
strategy.strategy_value[-1]
# Out:
# 997994.7486761098

# %%
strategy.test()

# %%
strategy.strategy_value[-1]
# Out:
# 997967.5615420999

# %%
# Convert the 'Date' column to datetime type
data['Date'] = pd.to_datetime(data['Date'])

# Get the closing price of the first and last data
first_close = data.iloc[0]['Close']
last_close = data.iloc[-1]['Close']

# Calculate the passive asset return
passive_return = (last_close - first_close) / first_close

print("The passive asset return from the first close to the last close is: {:.2%}".format(passive_return))

# Comparison with the strategy used
cash = 1000000
cash_final = 1107153.05
strategy_return = (cash_final - cash) / cash
print("The strategy return from the first close to the last close is: {:.2%}".format(strategy_return))

# Sort the data by date if they are not sorted
data = data.sort_values(by='Date')
plt.figure(figsize=(12, 8))
plt.plot(data['Date'], data['Close'], label='Closing Price', color='blue')
plt.title('Closing Price of the Asset')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend()
plt.grid(True)
plt.show()

# Calculate the cumulative return
data['Returns'] = data['Close'].pct_change().fillna(0)

# Calculate the cumulative value
initial_investment = cash
data['Investment_Value'] = (1 + data['Returns']).cumprod() * initial_investment
plt.figure(figsize=(12, 8))
plt.plot(data['Date'], data['Investment_Value'], label='Investment Value', color='green')
plt.title('Investment Return')
plt.xlabel('Date')
plt.ylabel('Investment Value')
plt.legend()
plt.grid(True)
plt.show()

final_value = data['Investment_Value'].iloc[-1]
print("The final value of the passive investment: ${:,.2f}".format(final_value))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26924\368900766.py in <module>
#       1 # Convert the 'Date' column to datetime type
# ----> 2 data['Date'] = pd.to_datetime(data['Date'])
#       3
#       4 # Get the closing price of the first and last data
#       5 first_close = data.iloc[0]['Close']
#
# NameError: name 'pd' is not defined
