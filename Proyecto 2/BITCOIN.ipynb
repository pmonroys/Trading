# %% [markdown]
# <img style="float: right; margin: 0px 0px 15px 15px;" src="https://educationusa.state.gov/sites/default/files/wysiwyg/iteso_logo.jpg" width="300px" height="300px" />
#
# `Trading Microstructure`
#
# **Ulises Rodrigo León Ortiz**
# **Bryan Edwin Castelan**
# **Paulina Raquel Monroy Salcido**
#
#
# ## 002 Technical Analysis

# %% [markdown]
# -Define buy/sell signals for each indicator.
# -Create all possible combinations of all technical indicators (2^5 - 1).
# -Backtest the strategies while keeping track of the operations and cash/portfolio value time series, remember that we'll be opening long & short positions.
# -Measure your strategy's Sharpe Ratio (using treasury bonds as reference), Max Drawdown and Win-Loss Ratio.
# -Optimize all technical indicator's parameters (TPE, Grid Search, PSO, Genetic Algorithms, ...), stop-loss/take-profit, volume of the trade, maximizing one of the previous metrics, consider the bounds of each variable!
# -Select the optimal strategy and describe it thoroughly (what indicators are used, when is the trade signal produced, etc.).
# -Now, use the optimal strategy with the test dataset and compare it to a passive strategy.

# %%
from TA import Operation, TechnicalAnalysis

# %%
strategy = TechnicalAnalysis('BITCOIN')
strategy

# %%
strategy.plot_ClosingPrices()

# %% [markdown]
# ### Relative Strength Index | RSI
#
# The Relative Strength Index (RSI) is a popular technical analysis tool used by traders to assess the momentum of an asset and pinpoint potential shifts in its trend. By evaluating whether an asset is overbought or oversold, the RSI provides traders with valuable signals, enabling them to make more strategic decisions in the market. This concise overview highlights the key principles of the RSI strategy and its effectiveness in helping traders navigate financial markets with greater precision.

# %%
strategy.plot_RSI()

# %% [markdown]
# The top graph illustrates the asset's closing prices over time, providing insight into its price fluctuations and trend trajectory. In the lower graph, the Relative Strength Index (RSI) is depicted, which is a momentum-based indicator that oscillates between 0 and 100. It highlights whether the asset could be considered overbought (values above 70) or oversold (values below 30). When the RSI crosses these upper (overbought) or lower (oversold) boundaries, it may signal potential reversal points or trend continuations. However, traders often combine the RSI with other technical tools to enhance the accuracy of their trading decisions.

# %% [markdown]
# ### Bollinger Bands
# Bollinger Bands are a technical analysis tool consisting of three lines: a middle band (usually a moving average) and two outer bands that represent standard deviations from the middle. These bands expand and contract based on market volatility. When prices move near the upper band, the asset may be considered overbought, while prices near the lower band might indicate an oversold condition. Traders use Bollinger Bands to identify potential price breakouts, reversals, and to assess market volatility.

# %%
strategy.plot_bollinger_bands()

# %% [markdown]
# The upper graph shows the closing prices of a financial asset, with Bollinger Bands overlaid to highlight price volatility. The middle line represents the asset’s moving average, while the outer bands indicate levels of standard deviation. When the price touches or moves close to the upper band, it may signal that the asset is overbought, while nearing the lower band could suggest an oversold condition. Traders often interpret price movements outside the bands as potential breakout signals, but it's essential to use Bollinger Bands alongside other indicators for more accurate trading decisions. The contraction or expansion of the bands also indicates changes in market volatility, with narrow bands suggesting low volatility and wide bands indicating high volatility.

# %% [markdown]
# ### Williams %R
# The Williams %R is a momentum oscillator that ranges from 0 to -100 and helps traders identify potential overbought or oversold conditions. In the strategy, a buy signal is triggered when the Williams %R falls below -80, indicating that the asset may be oversold, presenting a possible buying opportunity. A sell signal is generated when the Williams %R rises above -20, indicating the asset could be overbought and signaling a potential time to sell. This strategy aims to capture potential reversals in price trends by trading at these extreme conditions.

# %%
strategy.plot_williams_r()

# %% [markdown]
# The top graph shows the asset’s closing prices over time, reflecting the overall price movement and trends. In the lower graph, the Williams %R is plotted, ranging from 0 to -100. When the Williams %R dips below -80, it signals an oversold condition, prompting a buy signal. Conversely, when it rises above -20, an overbought condition is indicated, triggering a sell signal. These signals are intended to help traders identify potential entry and exit points based on momentum. However, it is recommended to use Williams %R in conjunction with other indicators for a more accurate analysis of market conditions.

# %% [markdown]
# ### MACD
# The Moving Average Convergence Divergence (MACD) is a popular trend-following indicator that tracks the relationship between two moving averages of an asset's price. The strategy uses two main components: the MACD line, which is the difference between the short-term and long-term moving averages, and the Signal Line, which is the moving average of the MACD line. In this strategy, a buy signal is generated when the MACD line crosses above the Signal Line, suggesting upward momentum. A sell signal is triggered when the MACD line crosses below the Signal Line, indicating potential downward momentum.

# %%
strategy.plot_MACD()
# Out:
# D:\Anaconda\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# The upper graph shows the asset’s closing prices over time, depicting its general trend and movement. In the lower graph, the MACD line and Signal Line are plotted. A buy signal occurs when the MACD line crosses above the Signal Line, signaling the beginning of potential bullish momentum. Conversely, when the MACD line crosses below the Signal Line, a sell signal is triggered, suggesting possible bearish momentum. This strategy aims to help traders identify trend shifts. To increase accuracy, it is often used alongside other indicators or confirmation tools to better gauge

# %% [markdown]
# ### Stochastic Oscillator Strategy
# The Stochastic Oscillator is a momentum indicator used to assess the position of an asset's price relative to its price range over a specific period. It consists of two lines: %K, which measures the current price relative to the high-low range, and %D, which is a moving average of %K. In this strategy, a buy signal is triggered when %K crosses above %D while both lines are below 20, indicating the asset may be oversold. Conversely, a sell signal is generated when %K crosses below %D while both lines are above 80, signaling that the asset could be overbought.

# %%
strategy.plot_stochastic()

# %% [markdown]
# The top graph represents the asset’s closing prices over time, highlighting the trend and price movements. In the lower graph, the Stochastic Oscillator is plotted, showing both the %K and %D lines. A buy signal is activated when %K crosses above %D while below the 20 level, indicating oversold conditions and a potential upward reversal. On the other hand, a sell signal occurs when %K crosses below %D while above the 80 level, suggesting overbought conditions and a potential downward reversal. This strategy helps traders identify entry and exit points, but it is often used in combination with other technical indicators to improve accuracy and reliability in trading decisions.

# %% [markdown]
# ### What's Max Drawdown?
#
# **Maximum Drawdown** measures the largest drop in value from a peak to a trough for an investment, before it reaches a new peak. It starts by calculating how much an investment has grown over time, and keeps track of the highest value it has reached. Then, it looks at how far the value falls from this highest point. The maximum drawdown is the biggest of these falls, expressed as a percentage. It's a useful way to understand the most significant risk of loss that has been experienced over a period, helping investors gauge how volatile or risky an investment might be.

# %% [markdown]
# ### Combinations
#
# In this section, combinations of strategies are tested. Strategies that together provide the best performance that have the the lowest MaxDrawdown ratio are selected, optimizing, and conducting backtesting.

# %%
strategy.run_combinations()
# Out:
# Ejecutando con combinación de indicadores: ['RSI']
# Ejecutando con combinación de indicadores: ['Bollinger']
# Ejecutando con combinación de indicadores: ['Williams %R']
# Ejecutando con combinación de indicadores: ['MACD']
# Ejecutando con combinación de indicadores: ['Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger']
# Ejecutando con combinación de indicadores: ['RSI', 'Williams %R']
# Ejecutando con combinación de indicadores: ['RSI', 'MACD']
# Ejecutando con combinación de indicadores: ['RSI', 'Stoch']
# Ejecutando con combinación de indicadores: ['Bollinger', 'Williams %R']
# Ejecutando con combinación de indicadores: ['Bollinger', 'MACD']
# Ejecutando con combinación de indicadores: ['Bollinger', 'Stoch']
# Ejecutando con combinación de indicadores: ['Williams %R', 'MACD']
# Ejecutando con combinación de indicadores: ['Williams %R', 'Stoch']
# Ejecutando con combinación de indicadores: ['MACD', 'Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger', 'Williams %R']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger', 'MACD']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger', 'Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'Williams %R', 'MACD']
# Ejecutando con combinación de indicadores: ['RSI', 'Williams %R', 'Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'MACD', 'Stoch']
# Ejecutando con combinación de indicadores: ['Bollinger', 'Williams %R', 'MACD']
# Ejecutando con combinación de indicadores: ['Bollinger', 'Williams %R', 'Stoch']
# Ejecutando con combinación de indicadores: ['Bollinger', 'MACD', 'Stoch']
# Ejecutando con combinación de indicadores: ['Williams %R', 'MACD', 'Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger', 'Williams %R', 'MACD']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger', 'Williams %R', 'Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger', 'MACD', 'Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'Williams %R', 'MACD', 'Stoch']
# Ejecutando con combinación de indicadores: ['Bollinger', 'Williams %R', 'MACD', 'Stoch']
# Ejecutando con combinación de indicadores: ['RSI', 'Bollinger', 'Williams %R', 'MACD', 'Stoch']
# Mejor combinación de indicadores: ['RSI'] con un valor de estrategia de: 0.5826148835680492

# %%
strategy.run_best()
# Out:
# Ejecutando con combinación de indicadores: ['RSI']
# Mejor combinación de indicadores: ['RSI'] con un Max Drawdown de: 0.5826148835680492

# %% [markdown]
# **The combination of strategies ['RSI'] achieves better performance together in the strategy.**

# %% [markdown]
# ### Optimize parameters
# Optuna for optimizing the parameters of these indicators. The optimization process aims to fine-tune the trading strategies to enhance their effectiveness in identifying optimal entry and exit points in the market so we have the lowest MaxDrawdown.

# %%
strategy.optimize_parameters()
# Out:
# [I 2024-09-28 16:50:23,363] A new study created in memory with name: no-name-53c505b3-d0a9-44d3-83c1-7ab2580a9b53
# [I 2024-09-28 17:03:54,354] Trial 0 finished with value: 0.8896297785208707 and parameters: {'n_shares': 0.031867221962848996, 'stop_loss': 0.09540759120979998, 'take_profit': 0.4461024653541334, 'rsi_window': 18}. Best is trial 0 with value: 0.8896297785208707.
# [I 2024-09-28 17:10:47,271] Trial 1 finished with value: 0.4892905931044275 and parameters: {'n_shares': 0.028565248650435894, 'stop_loss': 0.047904941095775505, 'take_profit': 0.3683604368511099, 'rsi_window': 10}. Best is trial 1 with value: 0.4892905931044275.
# [I 2024-09-28 17:19:14,067] Trial 2 finished with value: 0.9955992123501829 and parameters: {'n_shares': 0.06839166863755013, 'stop_loss': 0.055065261634063896, 'take_profit': 0.43867849725524366, 'rsi_window': 25}. Best is trial 1 with value: 0.4892905931044275.
# [I 2024-09-28 17:39:33,751] Trial 3 finished with value: 1.4894752484054732 and parameters: {'n_shares': 0.07906529546037316, 'stop_loss': 0.14694777565467834, 'take_profit': 0.4834956530470292, 'rsi_window': 30}. Best is trial 1 with value: 0.4892905931044275.
# [I 2024-09-28 17:47:06,484] Trial 4 finished with value: 0.37030749400253515 and parameters: {'n_shares': 0.07018281262792307, 'stop_loss': 0.11571400109829723, 'take_profit': 0.14722959659821233, 'rsi_window': 13}. Best is trial 4 with value: 0.37030749400253515.
# [I 2024-09-28 17:51:23,745] Trial 5 finished with value: 0.4547599695742878 and parameters: {'n_shares': 0.038169218152300725, 'stop_loss': 0.03261264248141932, 'take_profit': 0.25521868533192127, 'rsi_window': 20}. Best is trial 4 with value: 0.37030749400253515.
# [I 2024-09-28 18:02:22,237] Trial 6 finished with value: 0.9389640796113853 and parameters: {'n_shares': 0.049206346787386106, 'stop_loss': 0.07070495487689163, 'take_profit': 0.48865837321745487, 'rsi_window': 19}. Best is trial 4 with value: 0.37030749400253515.
# [I 2024-09-28 18:06:33,897] Trial 7 finished with value: 0.08724637355134457 and parameters: {'n_shares': 0.016619212878129872, 'stop_loss': 0.07257623463202914, 'take_profit': 0.0946375557870307, 'rsi_window': 10}. Best is trial 7 with value: 0.08724637355134457.
# [I 2024-09-28 18:10:30,856] Trial 8 finished with value: 0.5970356897071866 and parameters: {'n_shares': 0.05222023178411416, 'stop_loss': 0.03177509757467603, 'take_profit': 0.22267586738539563, 'rsi_window': 27}. Best is trial 7 with value: 0.08724637355134457.
# [I 2024-09-28 18:16:44,183] Trial 9 finished with value: 0.9600673095491368 and parameters: {'n_shares': 0.09169401271647157, 'stop_loss': 0.04490703823804214, 'take_profit': 0.34496255758315153, 'rsi_window': 11}. Best is trial 7 with value: 0.08724637355134457.
# [I 2024-09-28 18:21:58,241] Trial 10 finished with value: 0.4545659696523615 and parameters: {'n_shares': 0.025655566808667936, 'stop_loss': 0.19732485385652504, 'take_profit': 0.053006185570072445, 'rsi_window': 5}. Best is trial 7 with value: 0.08724637355134457.
# [I 2024-09-28 18:28:10,132] Trial 11 finished with value: 0.6509879242612423 and parameters: {'n_shares': 0.06801811754463645, 'stop_loss': 0.12861058160448252, 'take_profit': 0.10533655008179424, 'rsi_window': 12}. Best is trial 7 with value: 0.08724637355134457.
# [I 2024-09-28 18:34:47,120] Trial 12 finished with value: 0.16270990507740468 and parameters: {'n_shares': 0.013984954403581211, 'stop_loss': 0.09338368254766685, 'take_profit': 0.15266665559437073, 'rsi_window': 6}. Best is trial 7 with value: 0.08724637355134457.
# [I 2024-09-28 18:42:23,444] Trial 13 finished with value: 0.177584051302085 and parameters: {'n_shares': 0.010782789792017829, 'stop_loss': 0.09251364314360001, 'take_profit': 0.17814922227963287, 'rsi_window': 5}. Best is trial 7 with value: 0.08724637355134457.
# [I 2024-09-28 18:43:42,409] Trial 14 finished with value: 0.03805225897218879 and parameters: {'n_shares': 0.010054921260545427, 'stop_loss': 0.01149031080475886, 'take_profit': 0.054671359655351165, 'rsi_window': 7}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 18:45:02,219] Trial 15 finished with value: 0.05860476142318722 and parameters: {'n_shares': 0.015449758298176082, 'stop_loss': 0.011580372895283408, 'take_profit': 0.056274202314811395, 'rsi_window': 15}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 18:46:26,601] Trial 16 finished with value: 0.14496324253835483 and parameters: {'n_shares': 0.04035588565432264, 'stop_loss': 0.014368757271140701, 'take_profit': 0.050893669017835715, 'rsi_window': 15}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 18:48:26,606] Trial 17 finished with value: 0.16518079384217138 and parameters: {'n_shares': 0.02139492495609776, 'stop_loss': 0.010943865434115567, 'take_profit': 0.21371250595762925, 'rsi_window': 22}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 19:07:14,717] Trial 18 finished with value: 1.0188134577518506 and parameters: {'n_shares': 0.03810437707471346, 'stop_loss': 0.17031116846486283, 'take_profit': 0.33449805771924657, 'rsi_window': 15}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 19:09:37,472] Trial 19 finished with value: 0.08608703935342146 and parameters: {'n_shares': 0.011516378205863539, 'stop_loss': 0.023354345149026613, 'take_profit': 0.11727297844700285, 'rsi_window': 7}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 19:17:34,828] Trial 20 finished with value: 1.034858046255113 and parameters: {'n_shares': 0.09971114817854015, 'stop_loss': 0.06777961184124551, 'take_profit': 0.28244541057139005, 'rsi_window': 8}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 19:19:58,405] Trial 21 finished with value: 0.1259309644775869 and parameters: {'n_shares': 0.01820565392973059, 'stop_loss': 0.025496231291861744, 'take_profit': 0.10471356827885672, 'rsi_window': 7}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 19:21:25,209] Trial 22 finished with value: 0.04147922737986009 and parameters: {'n_shares': 0.010079847547657901, 'stop_loss': 0.011909790589396538, 'take_profit': 0.0763988346577121, 'rsi_window': 8}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 19:22:55,511] Trial 23 finished with value: 0.08955939557764708 and parameters: {'n_shares': 0.021536882117892953, 'stop_loss': 0.012634952523954192, 'take_profit': 0.07570561744358097, 'rsi_window': 15}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 19:26:51,636] Trial 24 finished with value: 0.13384150198473158 and parameters: {'n_shares': 0.010164933002582697, 'stop_loss': 0.04532938880224744, 'take_profit': 0.1430336660785691, 'rsi_window': 9}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 19:29:14,690] Trial 25 finished with value: 0.1865472448472066 and parameters: {'n_shares': 0.0320856088015114, 'stop_loss': 0.03323056098962679, 'take_profit': 0.07733755529775167, 'rsi_window': 16}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 19:34:59,437] Trial 26 finished with value: 0.3912701209885799 and parameters: {'n_shares': 0.024463422970205553, 'stop_loss': 0.061718599883440944, 'take_profit': 0.18507694554179574, 'rsi_window': 13}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 19:38:29,886] Trial 27 finished with value: 0.4280984597643872 and parameters: {'n_shares': 0.046156373299949774, 'stop_loss': 0.040871800557645124, 'take_profit': 0.12755034991149322, 'rsi_window': 21}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 19:40:03,188] Trial 28 finished with value: 0.09138105095888484 and parameters: {'n_shares': 0.019810809337156052, 'stop_loss': 0.013760760550598508, 'take_profit': 0.0792043006154391, 'rsi_window': 8}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 19:43:22,773] Trial 29 finished with value: 0.4259966431652085 and parameters: {'n_shares': 0.034255047587670284, 'stop_loss': 0.08557259019943261, 'take_profit': 0.05344357084562723, 'rsi_window': 18}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 19:46:24,744] Trial 30 finished with value: 0.30228654750726397 and parameters: {'n_shares': 0.02799798823892635, 'stop_loss': 0.02494017478299267, 'take_profit': 0.17651830231018523, 'rsi_window': 13}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 19:49:08,125] Trial 31 finished with value: 0.08579620459400712 and parameters: {'n_shares': 0.010040373859161315, 'stop_loss': 0.027480182513711086, 'take_profit': 0.1257530434046674, 'rsi_window': 7}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 19:51:11,870] Trial 32 finished with value: 0.09094585241563281 and parameters: {'n_shares': 0.016410630798645708, 'stop_loss': 0.021765406919399467, 'take_profit': 0.09169189589643056, 'rsi_window': 10}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 19:53:40,844] Trial 33 finished with value: 0.45869120600348534 and parameters: {'n_shares': 0.05938020994076574, 'stop_loss': 0.0564502493566415, 'take_profit': 0.05004769386136666, 'rsi_window': 8}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 19:57:03,088] Trial 34 finished with value: 0.1648973541517453 and parameters: {'n_shares': 0.014329228565651792, 'stop_loss': 0.039010200853007, 'take_profit': 0.12623378817609485, 'rsi_window': 5}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 20:00:00,680] Trial 35 finished with value: 0.15040586350380158 and parameters: {'n_shares': 0.026836345358210917, 'stop_loss': 0.04740622823043718, 'take_profit': 0.07851401205054925, 'rsi_window': 23}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 20:14:52,679] Trial 36 finished with value: 0.7664257267694452 and parameters: {'n_shares': 0.020915856658326112, 'stop_loss': 0.11242698206910234, 'take_profit': 0.4125264511251343, 'rsi_window': 11}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 20:16:34,477] Trial 37 finished with value: 0.061990482041553545 and parameters: {'n_shares': 0.010615813689751235, 'stop_loss': 0.010694183714340454, 'take_profit': 0.1380776255048716, 'rsi_window': 9}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 20:18:24,190] Trial 38 finished with value: 0.20453676997117218 and parameters: {'n_shares': 0.03160519724599214, 'stop_loss': 0.011039083870388409, 'take_profit': 0.1590467446668618, 'rsi_window': 17}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 20:33:30,965] Trial 39 finished with value: 0.4194100033512767 and parameters: {'n_shares': 0.016331460522582754, 'stop_loss': 0.14669910810253628, 'take_profit': 0.2725276196001637, 'rsi_window': 9}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 20:39:21,577] Trial 40 finished with value: 0.4184148162296468 and parameters: {'n_shares': 0.0245461009349556, 'stop_loss': 0.058180813664256203, 'take_profit': 0.201210646969969, 'rsi_window': 12}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 20:42:18,956] Trial 41 finished with value: 0.10682981211787917 and parameters: {'n_shares': 0.010565040166993927, 'stop_loss': 0.03170821137401976, 'take_profit': 0.1250801333846416, 'rsi_window': 7}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 20:44:31,177] Trial 42 finished with value: 0.0865445040776955 and parameters: {'n_shares': 0.015020726119721606, 'stop_loss': 0.02264828433570462, 'take_profit': 0.09597250599237084, 'rsi_window': 9}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 20:48:39,256] Trial 43 finished with value: 0.23615866941746044 and parameters: {'n_shares': 0.017230516996049047, 'stop_loss': 0.03196220341082567, 'take_profit': 0.245782889073001, 'rsi_window': 6}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 20:50:30,266] Trial 44 finished with value: 0.04951527722477505 and parameters: {'n_shares': 0.010646140066049728, 'stop_loss': 0.020785499559130567, 'take_profit': 0.07615883476258022, 'rsi_window': 30}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 20:52:17,819] Trial 45 finished with value: 0.30304880857689964 and parameters: {'n_shares': 0.07975061524334509, 'stop_loss': 0.020668447665442076, 'take_profit': 0.06903726877388185, 'rsi_window': 29}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 20:55:23,837] Trial 46 finished with value: 0.1970941355710667 and parameters: {'n_shares': 0.020726270942376442, 'stop_loss': 0.038128365531383046, 'take_profit': 0.1051188761041083, 'rsi_window': 24}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 20:58:58,506] Trial 47 finished with value: 0.5067250880933333 and parameters: {'n_shares': 0.058838292601811254, 'stop_loss': 0.0792062502125864, 'take_profit': 0.06475319138459945, 'rsi_window': 28}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 21:01:10,173] Trial 48 finished with value: 0.10944342728011507 and parameters: {'n_shares': 0.014646739024076984, 'stop_loss': 0.017456726208622847, 'take_profit': 0.1493253817203506, 'rsi_window': 26}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 21:04:38,106] Trial 49 finished with value: 0.18853710619731673 and parameters: {'n_shares': 0.02423026035834649, 'stop_loss': 0.04844440090671455, 'take_profit': 0.09911947318628866, 'rsi_window': 19}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 21:06:06,580] Trial 50 finished with value: 0.054610580273313655 and parameters: {'n_shares': 0.013528328240432059, 'stop_loss': 0.010829987607466557, 'take_profit': 0.0852480041475116, 'rsi_window': 11}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 21:07:32,907] Trial 51 finished with value: 0.052188760100217814 and parameters: {'n_shares': 0.013375580451590154, 'stop_loss': 0.010172489200886392, 'take_profit': 0.08270414240485771, 'rsi_window': 11}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 21:09:34,983] Trial 52 finished with value: 0.07970121220903946 and parameters: {'n_shares': 0.014848341001124095, 'stop_loss': 0.021200173208343914, 'take_profit': 0.0887566719351553, 'rsi_window': 11}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 21:11:13,837] Trial 53 finished with value: 0.07516763868138297 and parameters: {'n_shares': 0.018885336318569354, 'stop_loss': 0.01839702372769187, 'take_profit': 0.06320666980290157, 'rsi_window': 12}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 21:13:57,755] Trial 54 finished with value: 0.11605675191723211 and parameters: {'n_shares': 0.013277136784323688, 'stop_loss': 0.02959413464274981, 'take_profit': 0.11130867972760787, 'rsi_window': 14}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 21:15:26,974] Trial 55 finished with value: 0.0898187988683338 and parameters: {'n_shares': 0.02246637596981486, 'stop_loss': 0.010639549661351003, 'take_profit': 0.08643240852865794, 'rsi_window': 10}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 21:17:49,439] Trial 56 finished with value: 0.12297720755521453 and parameters: {'n_shares': 0.030032523920520752, 'stop_loss': 0.0378944228114594, 'take_profit': 0.06572753042721825, 'rsi_window': 14}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 21:22:48,383] Trial 57 finished with value: 0.34745685909586815 and parameters: {'n_shares': 0.01838148500867689, 'stop_loss': 0.18435176509965157, 'take_profit': 0.050285845264596875, 'rsi_window': 17}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 21:32:23,393] Trial 58 finished with value: 0.13510408734798304 and parameters: {'n_shares': 0.013284135287230044, 'stop_loss': 0.13483013076851838, 'take_profit': 0.16350782200280478, 'rsi_window': 30}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 21:35:28,812] Trial 59 finished with value: 0.38646255572517535 and parameters: {'n_shares': 0.04347002545264161, 'stop_loss': 0.018234309619791007, 'take_profit': 0.32674375348316775, 'rsi_window': 6}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 21:38:08,408] Trial 60 finished with value: 0.26602812202690046 and parameters: {'n_shares': 0.03549084761761874, 'stop_loss': 0.027393930093209867, 'take_profit': 0.11528543430889236, 'rsi_window': 12}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 21:39:50,587] Trial 61 finished with value: 0.07157799185674724 and parameters: {'n_shares': 0.012298630831744723, 'stop_loss': 0.010711822595253532, 'take_profit': 0.1373380242166827, 'rsi_window': 10}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 21:41:32,937] Trial 62 finished with value: 0.058029581351112705 and parameters: {'n_shares': 0.011907059578832114, 'stop_loss': 0.01656362932371768, 'take_profit': 0.08210616311884521, 'rsi_window': 9}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 21:45:13,237] Trial 63 finished with value: 0.197237688603188 and parameters: {'n_shares': 0.01785589562022922, 'stop_loss': 0.01766770452019049, 'take_profit': 0.4658957134715344, 'rsi_window': 8}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 21:47:47,072] Trial 64 finished with value: 0.06740202540004347 and parameters: {'n_shares': 0.010026980736746299, 'stop_loss': 0.03452699097403683, 'take_profit': 0.08133158867213064, 'rsi_window': 11}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 21:51:46,982] Trial 65 finished with value: 0.3241355820224582 and parameters: {'n_shares': 0.023154956694611113, 'stop_loss': 0.09992090951711405, 'take_profit': 0.06348525828545232, 'rsi_window': 14}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 21:54:17,255] Trial 66 finished with value: 0.0988300402495729 and parameters: {'n_shares': 0.013072375729848982, 'stop_loss': 0.025645193367582177, 'take_profit': 0.10784957464411851, 'rsi_window': 6}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 21:57:26,281] Trial 67 finished with value: 0.46329817781300436 and parameters: {'n_shares': 0.07281354472861777, 'stop_loss': 0.042447622824231784, 'take_profit': 0.09399291643585933, 'rsi_window': 16}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 22:00:27,293] Trial 68 finished with value: 0.11814118687523828 and parameters: {'n_shares': 0.027117905710673452, 'stop_loss': 0.051545204475836576, 'take_profit': 0.0740915637076282, 'rsi_window': 20}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 22:03:51,330] Trial 69 finished with value: 0.1932912887955947 and parameters: {'n_shares': 0.01938894024248091, 'stop_loss': 0.018234562458849277, 'take_profit': 0.41628556027762, 'rsi_window': 8}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 22:05:32,264] Trial 70 finished with value: 0.07949375463184659 and parameters: {'n_shares': 0.01598174232096561, 'stop_loss': 0.014564522241391653, 'take_profit': 0.08790599928726137, 'rsi_window': 11}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 22:07:16,512] Trial 71 finished with value: 0.070780188865893 and parameters: {'n_shares': 0.011972064831546596, 'stop_loss': 0.011185670453148272, 'take_profit': 0.1367931555800153, 'rsi_window': 9}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 22:09:11,029] Trial 72 finished with value: 0.046347557075619446 and parameters: {'n_shares': 0.010255091557190489, 'stop_loss': 0.025736326497159425, 'take_profit': 0.059136499841755855, 'rsi_window': 10}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 22:11:05,168] Trial 73 finished with value: 0.06726147883257239 and parameters: {'n_shares': 0.01612663021165579, 'stop_loss': 0.027396273015688016, 'take_profit': 0.0582700740760304, 'rsi_window': 13}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 22:13:33,029] Trial 74 finished with value: 0.07890912911812167 and parameters: {'n_shares': 0.01304366167775169, 'stop_loss': 0.035649693264848535, 'take_profit': 0.07443798907565122, 'rsi_window': 7}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 22:15:18,027] Trial 75 finished with value: 0.09629202747198864 and parameters: {'n_shares': 0.020967477612495455, 'stop_loss': 0.02364050375375628, 'take_profit': 0.05110462154897138, 'rsi_window': 10}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 22:17:14,526] Trial 76 finished with value: 0.06020019947949219 and parameters: {'n_shares': 0.010058648680280193, 'stop_loss': 0.01538133449912854, 'take_profit': 0.11903697582381108, 'rsi_window': 10}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 22:19:50,868] Trial 77 finished with value: 0.1316819729626993 and parameters: {'n_shares': 0.017171796346534964, 'stop_loss': 0.029604383547951474, 'take_profit': 0.10022976383612853, 'rsi_window': 9}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 22:21:46,356] Trial 78 finished with value: 0.06301441594134824 and parameters: {'n_shares': 0.013050729612052558, 'stop_loss': 0.022462890674499695, 'take_profit': 0.07514871348430438, 'rsi_window': 5}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 22:23:30,729] Trial 79 finished with value: 0.09248684990068491 and parameters: {'n_shares': 0.019212177541353327, 'stop_loss': 0.015749597162847268, 'take_profit': 0.08378120581097763, 'rsi_window': 8}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 22:27:44,298] Trial 80 finished with value: 0.41988765315011667 and parameters: {'n_shares': 0.08345398984067251, 'stop_loss': 0.06633825921037277, 'take_profit': 0.10307007401722167, 'rsi_window': 12}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 22:29:37,485] Trial 81 finished with value: 0.057170429187581494 and parameters: {'n_shares': 0.010124908384276324, 'stop_loss': 0.015208414780219212, 'take_profit': 0.11334661927347002, 'rsi_window': 10}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 22:31:22,896] Trial 82 finished with value: 0.05430528859015114 and parameters: {'n_shares': 0.012262796459233867, 'stop_loss': 0.0213062607430249, 'take_profit': 0.06238106920555217, 'rsi_window': 11}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 22:33:35,204] Trial 83 finished with value: 0.06441652104330371 and parameters: {'n_shares': 0.014832924679269945, 'stop_loss': 0.031598632993066395, 'take_profit': 0.0658631436266359, 'rsi_window': 9}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 22:37:03,494] Trial 84 finished with value: 0.13774057293224118 and parameters: {'n_shares': 0.011757972318703258, 'stop_loss': 0.021906613830600552, 'take_profit': 0.3077933952355645, 'rsi_window': 7}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 22:40:07,508] Trial 85 finished with value: 0.10589301093777324 and parameters: {'n_shares': 0.015068924624816803, 'stop_loss': 0.042789552292697264, 'take_profit': 0.08760478713552243, 'rsi_window': 11}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 22:41:58,659] Trial 86 finished with value: 0.06741091462565454 and parameters: {'n_shares': 0.012057611475365118, 'stop_loss': 0.014866095427563227, 'take_profit': 0.11388592740278089, 'rsi_window': 13}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 22:43:56,076] Trial 87 finished with value: 0.09859570386746115 and parameters: {'n_shares': 0.02232567722313753, 'stop_loss': 0.025256476716018612, 'take_profit': 0.06313451981676951, 'rsi_window': 10}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 22:46:19,661] Trial 88 finished with value: 0.057335167379112956 and parameters: {'n_shares': 0.010017731137722426, 'stop_loss': 0.034506187983797273, 'take_profit': 0.07389669340683563, 'rsi_window': 6}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 22:49:11,755] Trial 89 finished with value: 0.08593786992227695 and parameters: {'n_shares': 0.010057242972178538, 'stop_loss': 0.03489765204567136, 'take_profit': 0.09678085173676473, 'rsi_window': 6}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 22:52:46,992] Trial 90 finished with value: 0.19078838988383698 and parameters: {'n_shares': 0.017306323892178198, 'stop_loss': 0.02073266300380624, 'take_profit': 0.3741186172401567, 'rsi_window': 6}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 22:54:24,594] Trial 91 finished with value: 0.060639854409305013 and parameters: {'n_shares': 0.013697542856770484, 'stop_loss': 0.015504409422296108, 'take_profit': 0.07154837871934479, 'rsi_window': 8}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 22:55:43,727] Trial 92 finished with value: 0.04482101162201903 and parameters: {'n_shares': 0.012210171979835793, 'stop_loss': 0.010404293665208926, 'take_profit': 0.05753987947186771, 'rsi_window': 9}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 22:57:35,298] Trial 93 finished with value: 0.07020981042479844 and parameters: {'n_shares': 0.015896817085159706, 'stop_loss': 0.02855873726488063, 'take_profit': 0.050057687757470104, 'rsi_window': 7}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 22:58:57,614] Trial 94 finished with value: 0.18782012597796552 and parameters: {'n_shares': 0.05483040390557284, 'stop_loss': 0.010232705041205303, 'take_profit': 0.06334312170917741, 'rsi_window': 5}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 23:00:20,973] Trial 95 finished with value: 0.07237980331877963 and parameters: {'n_shares': 0.0198090153334413, 'stop_loss': 0.010095500759803514, 'take_profit': 0.07374770091890427, 'rsi_window': 11}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 23:02:01,290] Trial 96 finished with value: 0.05474349977536372 and parameters: {'n_shares': 0.01417654764119712, 'stop_loss': 0.01988455162002059, 'take_profit': 0.05836379321574879, 'rsi_window': 10}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 23:03:48,497] Trial 97 finished with value: 0.06299210554904712 and parameters: {'n_shares': 0.014292274971745497, 'stop_loss': 0.021252369311874915, 'take_profit': 0.059308984403931855, 'rsi_window': 12}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 23:06:04,562] Trial 98 finished with value: 0.11306920937539852 and parameters: {'n_shares': 0.017999674339088074, 'stop_loss': 0.02590326911945271, 'take_profit': 0.08838767329378515, 'rsi_window': 10}. Best is trial 14 with value: 0.03805225897218879.
# [I 2024-09-28 23:15:18,711] Trial 99 finished with value: 0.39403844251034326 and parameters: {'n_shares': 0.02545829631833702, 'stop_loss': 0.16569438122066163, 'take_profit': 0.1270371776362188, 'rsi_window': 11}. Best is trial 14 with value: 0.03805225897218879.
# Parámetros óptimos: {'n_shares': 0.010054921260545427, 'stop_loss': 0.01149031080475886, 'take_profit': 0.054671359655351165, 'rsi_window': 7}

# %% [markdown]
# **The optimal parameters for the strategy are {'n_shares': 0.010054921260545427, 'stop_loss': 0.01149031080475886, 'take_profit': 0.054671359655351165, 'rsi_window': 7}**
# , with a max drawdown of   **3.8052%**

# %% [markdown]
# Having optimized the parameters, we proceed to implement a strategy using the best parameters for the test dataset.

# %% [markdown]
# ### Comparation

# %%
strategy.plot_results()

# %%
passive_max_drawdown = strategy.passive_max_drawdown()
# Out:
# En estrategía pasiva el Max Drawdown es de: 0.5107043828339832

# %% [markdown]
# ### Test with Optimized Parameters

# %%
from TA import TestStrategy

# %%
strategy = TestStrategy('BITCOIN')
strategy

# %%
strategy.run_best()
# Out:
# Ejecutando con combinación de indicadores: ['RSI']
# Mejor combinación de indicadores: ['RSI'] con un Max Drawdown de: 0.06726909385617101

# %%
strategy.plot_results()

# %%
passive_max_drawdown = strategy.passive_max_drawdown()
# Out:
# En estrategía pasiva el Max Drawdown es de: 0.07877657533646004

# %% [markdown]
# After optimizing the parameters for the strategies in training, they are used to test the strategy on the test dataset, yielding a Max Drawdown of **6.7269%** compared to a **7.87%** in the passive strategy

# %% [markdown]
# Although our strategy yields lower returns compared to a passive strategy, our main goal was to minimize the maximum drawdown. This way, we avoid large losses if BITCOIN price fails to recover. We can conclude that this strategy could be beneficial during bearish or volatile periods, as it helps reduce portfolio risk by lowering the maximum drawdown.
